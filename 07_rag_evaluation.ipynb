# %%
import polars as pl
import os, math, string
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline
from peft import PeftModel
from transformers import BitsAndBytesConfig
import torch
import gc
from tqdm import tqdm
import numpy as np
import markdown

import lancedb
import nltk
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
from nltk.translate.meteor_score import meteor_score
from nltk.tokenize import word_tokenize, wordpunct_tokenize
from rouge_score import rouge_scorer
from bert_score import score as bertscore
from collections import Counter
import string
import random
import emoji

# === NLTK SETUP ===
nltk.download('punkt_tab')
nltk.download("wordnet")
smooth_fn = SmoothingFunction().method4
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/zorin17/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/zorin17/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
from huggingface_hub import login

# Insert your token here
login(token="")

# %%
gc.collect()
torch.cuda.empty_cache()
torch.cuda.ipc_collect()

# %%
df = pl.read_csv('hf://datasets/bitext/Bitext-customer-support-llm-chatbot-training-dataset/Bitext_Sample_Customer_Support_Training_Dataset_27K_responses-v11.csv')
# Data cleaning
# fill in null
df = df.with_columns([
    pl.col("instruction")
      .cast(str)
      .str.to_lowercase()
      .fill_null(""),
    
    pl.col("response")
      .cast(str)
      .str.to_lowercase()
      .fill_null(""),
    
    pl.col("intent")
      .cast(str)
      .fill_null("unknown")
])

# Remove emoji
def remove_emojis(text: str) -> str:
    return emoji.replace_emoji(text, replace="")  # Remove all emojis safely

# Apply to instruction and response
df = df.with_columns([
    pl.col("instruction").map_elements(remove_emojis).alias("instruction")
])

df = df.with_columns([
    pl.col("response").map_elements(remove_emojis).alias("response")
])

#Exclude noisy flags
# Filter out rows where 'flags' contains Z, Q, or W ===
flag = ["flags"]
df_z = df.filter(
    ~pl.col(flag).cast(str).str.contains("Z")
)

df_zw = df.filter(
    ~pl.col(flag).cast(str).str.contains("Z") &
    ~pl.col(flag).cast(str).str.contains("W")
)

df_clean = df.filter(
    ~pl.col(flag).cast(str).str.contains("Z") &
    ~pl.col(flag).cast(str).str.contains("W") &
    ~pl.col(flag).cast(str).str.contains("Q")
)

print(df_z.height)
print(df_zw.height)
print(df_clean.height)

category_counts = (
    df_clean
    .group_by("category")
    .agg(pl.count().alias("counts"))
    .sort("counts", descending=True)
)

print(category_counts)

# Filter only selected categories
selected_categories = ["ORDER", "REFUND", "SHIPPING", "DELIVERY"]
df_selected = df_clean.filter(
    pl.col("category").is_in(selected_categories)
)

# %%
# Split dataset by category
# === Configuration ===
LABEL_COL = "category"  # 🔁 Replace with "intent" or any stratification column
SPLIT_RATIO_TRAIN = 0.7
SPLIT_RATIO_VAL = 0.15
SEED = 123
df_final = df_selected.clone()

# === Stratified split logic ===
random.seed(SEED)
train_parts = []
test_parts = []
val_parts = []

for label in df_final[LABEL_COL].unique().to_list():
    group_df = df_final.filter(pl.col(LABEL_COL) == label)
    group_df = group_df.sample(n=len(group_df), shuffle=True, seed=SEED)

    n = len(group_df)
    train_idx = int(n * SPLIT_RATIO_TRAIN)
    val_idx = int(n * (SPLIT_RATIO_TRAIN + SPLIT_RATIO_VAL))

    train_parts.append(group_df[:train_idx])
    val_parts.append(group_df[train_idx:val_idx])
    test_parts.append(group_df[val_idx:])

# === Combine all groups
train_df = pl.concat(train_parts).sort(["category", "instruction"])
val_df = pl.concat(val_parts).sort(["category", "instruction"])
test_df = pl.concat(test_parts).sort(["category", "instruction"])

print("✅ Split sizes:")
print(f"Train: {len(train_df)}")
print(f"Val:   {len(val_df)}")
print(f"Test:  {len(test_df)}")

print("\n📊 Category distribution in test set:")
print(test_df.select([pl.col(LABEL_COL)]).to_series().value_counts())
# Out:
# ✅ Split sizes:
# Train: 4154
# Val:   890
# Test:  893
#
# 📊 Category distribution in test set:
# shape: (4, 2)
# ┌──────────┬───────┐
# │ category ┆ count │
# │ ---      ┆ ---   │
# │ str      ┆ u32   │
# ╞══════════╪═══════╡
# │ DELIVERY ┆ 166   │
# │ ORDER    ┆ 323   │
# │ REFUND   ┆ 230   │
# │ SHIPPING ┆ 174   │
# └──────────┴───────┘

# %%
# === Configuration ===
scenario_no = "D"
scenario    = "rag_original"  

generate_models = {
    # "llama": "meta-llama/Llama-3.2-1B",
    "qwen":  "Qwen/Qwen3-0.6B-Base",
    # "olmo":  "allenai/OLMo-2-0425-1B",
}

OFFLOAD_DIR = "./offload"
USE_CUDA = torch.cuda.is_available()
SAVE_EVERY = 20

# === Load test set (pre-split externally)
questions = test_df["instruction"].cast(str).to_list()
answers = test_df["response"].cast(str).to_list()

# ----------------- RAG pieces -----------------

# Read data from LanceDB table
def load_faq_table():
    db = lancedb.connect("/home/zorin17/Desktop/LLM/")
    return db.open_table("LANCEDB_FAQ")

table = load_faq_table()

# Search reranker
def search(query, table, top_k=5, category=None, intent=None):
    s = table.search(query).limit(top_k)
    if category:
        s = s.where(f"category = '{category}'")
    if intent:
        s = s.where(f"intent = '{intent}'")

    result = s.to_list()
    if not result:
        return "[Context 1]:\n(no relevant context found)\n"

    blocks = []
    for i, r in enumerate(result, 1):
        text = (r.get("text") or "").strip()
        # optional: guard against empty rows
        if not text:
            text = "(empty context)"
        blocks.append(f"[Context {i}]:\n{text}\n")
    return "\n".join(blocks)

# Prompt template (system + user with explicit sections)
base_prompt = """You are a helpful retail assistant. Your task is to answer the user question using provided contexts as the answer. 
You must make your response organized and structured.

User question: {}
Contexts:
{}
"""

custom_template = """{% if messages | selectattr('role','equalto','system') | list %}
System: {{ (messages | selectattr('role','equalto','system') | map(attribute='content') | list) | join('\\n') }}
{% endif %}
{% for m in messages %}
{% if m['role'] == 'user' -%}
User: {{ m['content'] }}
{% elif m['role'] == 'assistant' -%}
Assistant: {{ m['content'] }}
{% elif m['role'] == 'tool' -%}
Tool: {{ m['content'] }}
{% elif m['role'] == 'developer' -%}
System: {{ m['content'] }}
{% else -%}
{{ m['role']|capitalize }}: {{ m['content'] }}
{% endif -%}
{% endfor %}
Assistant:"""

# ----------------- RAG pieces End -----------------

# === Safe append function
def append_to_csv(new_data: pl.DataFrame, path: str):
    if os.path.exists(path):
        existing = pl.read_csv(path)
        combined = existing.vstack(new_data)
    else:
        combined = new_data
    combined.write_csv(path)

def adaptive_max_new_tokens(gold_text: str, tokenizer, min_nt=48, max_nt=300, mult=1.3, bonus=16) -> int:
    n_gold = len(tokenizer(gold_text, add_special_tokens=False).input_ids)
    est = int(round(mult * n_gold) + bonus)
    return int(np.clip(est, min_nt, max_nt))

def _count_tokens(s, tok): 
    return len(tok(s, add_special_tokens=False).input_ids)

def safe_pack_contexts(question, contexts, tokenizer, max_src_tokens=700):
    head = "You are a helpful retail assistant. Your task is to answer the user question using provided contexts as the answer.\n\n"
    used = _count_tokens(head + f"User question: {question}\nContexts:\n", tokenizer)
    kept, buf = [], contexts.splitlines()
    for c in buf:
        block = c.strip() + "\n"
        t = _count_tokens(block, tokenizer)
        if used + t > max_src_tokens:
            break
        kept.append(block); used += t
    return "".join(kept)

def generate_one(tokenizer, hf_model, base_prompt, question, context,
                 temperature=0.0, max_new_tokens=128, return_html=False):
    system_content = base_prompt.format(question, context)
    messages = [
        {"role": "system", "content": system_content},
        {"role": "user",   "content": f"Question: {question}\n\nContext:\n{context}"}
    ]
    prompt = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True,
        chat_template=custom_template
    )
    inputs = tokenizer(prompt, return_tensors="pt").to(hf_model.device)
    input_len = inputs["input_ids"].shape[-1]

    with torch.inference_mode():
        outputs = hf_model.generate(
            **inputs,
            do_sample=(temperature > 0),
            temperature=temperature,
            top_p=0.95,
            max_new_tokens=max_new_tokens,
            no_repeat_ngram_size=3,
            eos_token_id=tokenizer.eos_token_id,
            pad_token_id=tokenizer.pad_token_id,
            return_dict_in_generate=True,
        )

    new_tokens = outputs.sequences[0, input_len:]
    text = tokenizer.decode(new_tokens, skip_special_tokens=True).strip()
    return markdown.markdown(text) if return_html else text

def rag_answer(tokenizer, hf_model, question, temperature=0.0, category=None, intent=None, max_new_tokens=128):
    raw_ctx = search(question, table, top_k=5, category=category, intent=intent)
    context = safe_pack_contexts(question, raw_ctx, tokenizer, max_src_tokens=700)
    return generate_one(tokenizer, hf_model, base_prompt, question, context,
                        temperature=temperature, max_new_tokens=max_new_tokens, return_html=False)

# ----------------- Run all base models -----------------
for key, MODEL_NAME in generate_models.items():
    OUTPUT_CSV = f"chatbot_result/{scenario}/scenario_{scenario_no}_{scenario}_results_{key}.csv"
    print(f"\n🚀 Scenario {scenario_no} (RAG Original) — Inference for: {MODEL_NAME}")
    os.makedirs(os.path.dirname(OUTPUT_CSV), exist_ok=True)

    # load tokenizer + model
    tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME, use_fast=True, trust_remote_code=True)
    if tokenizer.pad_token is None:
        tokenizer.pad_token = tokenizer.eos_token
    tokenizer.padding_side = "right"

    supports_bf16 = torch.cuda.is_available() and torch.cuda.get_device_capability(0)[0] >= 8
    hf_model = AutoModelForCausalLM.from_pretrained(
        MODEL_NAME,
        torch_dtype=torch.bfloat16 if supports_bf16 else (torch.float16 if USE_CUDA else torch.float32),
        device_map="auto",
        attn_implementation="sdpa",
        trust_remote_code=True,
        offload_folder=OFFLOAD_DIR
    )
    if getattr(hf_model.config, "use_cache", None) is not True:
        hf_model.config.use_cache = True

    # resume
    if os.path.exists(OUTPUT_CSV):
        existing = pl.read_csv(OUTPUT_CSV)
        done = set(existing["instruction"].to_list())
        print(f"🔄 Resuming from {len(done)} rows...")
    else:
        done = set()

    results = []
    for question, gold in tqdm(zip(questions, answers), total=len(questions), desc=f"{key.upper()} RAG"):
        if question in done:
            continue

        # adaptive cap per example
        max_nt = adaptive_max_new_tokens(gold, tokenizer, min_nt=48, max_nt=300, mult=1.3, bonus=16)

        try:
            pred = rag_answer(tokenizer, hf_model, question, temperature=0.0,
                              category=None, intent=None, max_new_tokens=max_nt)

            # strip possible “Assistant:” echo if template returns it
            if "Assistant:" in pred:
                pred = pred.split("Assistant:")[-1].strip()

        except Exception as e:
            print(f"⚠️ Error on: {question[:60]}... Skip. Reason: {e}")
            continue

        results.append((question, gold, pred))

        if len(results) >= SAVE_EVERY:
            chunk_df = pl.DataFrame(results, schema=["instruction", "response", "prediction"])
            enriched = test_df.join(chunk_df, on=["instruction", "response"], how="inner")
            append_to_csv(enriched, OUTPUT_CSV)
            results = []

    if results:
        chunk_df = pl.DataFrame(results, schema=["instruction", "response", "prediction"])
        enriched = test_df.join(chunk_df, on=["instruction", "response"], how="inner")
        append_to_csv(enriched, OUTPUT_CSV)

    print(f"✅ Done with {key}. Results saved to {OUTPUT_CSV}")

    # cleanup
    del tokenizer, hf_model
    gc.collect()
    torch.cuda.empty_cache()
    torch.cuda.ipc_collect()
# Out:
# 🚀 Scenario D (RAG Original) — Inference for: allenai/OLMo-2-0425-1B
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# OLMO RAG:   0%|          | 0/893 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   0%|          | 1/893 [00:08<2:05:36,  8.45s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   0%|          | 2/893 [00:10<1:07:43,  4.56s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   0%|          | 3/893 [00:12<48:58,  3.30s/it]  The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   0%|          | 4/893 [00:13<36:21,  2.45s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   1%|          | 5/893 [00:19<56:27,  3.81s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   1%|          | 6/893 [00:26<1:14:24,  5.03s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   1%|          | 7/893 [00:32<1:18:21,  5.31s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   1%|          | 8/893 [00:33<58:31,  3.97s/it]  The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   1%|          | 9/893 [00:34<45:26,  3.08s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   1%|          | 10/893 [00:36<36:32,  2.48s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   1%|          | 11/893 [00:37<30:29,  2.07s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   1%|▏         | 12/893 [00:38<26:33,  1.81s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   1%|▏         | 13/893 [00:39<23:19,  1.59s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   2%|▏         | 14/893 [00:42<27:16,  1.86s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   2%|▏         | 15/893 [00:43<26:55,  1.84s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   2%|▏         | 16/893 [00:45<27:14,  1.86s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   2%|▏         | 17/893 [00:46<23:54,  1.64s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   2%|▏         | 18/893 [00:48<24:40,  1.69s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   2%|▏         | 19/893 [00:54<42:32,  2.92s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# /home/zorin17/miniconda3/envs/llm/lib/python3.10/functools.py:889: DataOrientationWarning: Row orientation inferred during DataFrame construction. Explicitly specify the orientation by passing `orient="row"` to silence this warning.
#   return dispatch(args[0].__class__)(*args, **kw)
# OLMO RAG:   2%|▏         | 20/893 [00:56<37:49,  2.60s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   2%|▏         | 21/893 [00:57<31:45,  2.19s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   2%|▏         | 22/893 [00:59<29:01,  2.00s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   3%|▎         | 23/893 [01:13<1:23:41,  5.77s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   3%|▎         | 24/893 [01:15<1:06:30,  4.59s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   3%|▎         | 25/893 [01:17<54:27,  3.76s/it]  The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   3%|▎         | 26/893 [01:19<46:00,  3.18s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   3%|▎         | 27/893 [01:23<52:47,  3.66s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   3%|▎         | 28/893 [01:25<44:25,  3.08s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   3%|▎         | 29/893 [01:30<50:40,  3.52s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   3%|▎         | 30/893 [01:34<54:58,  3.82s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   3%|▎         | 31/893 [01:36<45:14,  3.15s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   4%|▎         | 32/893 [01:37<38:20,  2.67s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   4%|▎         | 33/893 [01:39<34:45,  2.43s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   4%|▍         | 34/893 [01:40<29:41,  2.07s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   4%|▍         | 35/893 [01:47<46:58,  3.29s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   4%|▍         | 36/893 [01:48<38:31,  2.70s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   4%|▍         | 37/893 [01:58<1:11:19,  5.00s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   4%|▍         | 38/893 [02:00<55:25,  3.89s/it]  The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   4%|▍         | 39/893 [02:20<2:04:02,  8.72s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   4%|▍         | 40/893 [02:21<1:32:19,  6.49s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   5%|▍         | 41/893 [02:22<1:10:03,  4.93s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   5%|▍         | 42/893 [02:24<56:26,  3.98s/it]  The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   5%|▍         | 43/893 [02:26<47:04,  3.32s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   5%|▍         | 44/893 [02:28<41:05,  2.90s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   5%|▌         | 45/893 [02:29<35:07,  2.49s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   5%|▌         | 46/893 [02:35<48:53,  3.46s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   5%|▌         | 47/893 [02:36<39:12,  2.78s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   5%|▌         | 48/893 [02:38<33:56,  2.41s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   5%|▌         | 49/893 [02:39<28:47,  2.05s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   6%|▌         | 50/893 [02:41<27:51,  1.98s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   6%|▌         | 51/893 [02:42<25:11,  1.80s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   6%|▌         | 52/893 [02:48<41:19,  2.95s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   6%|▌         | 53/893 [02:49<36:22,  2.60s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   6%|▌         | 54/893 [03:00<1:08:45,  4.92s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   6%|▌         | 55/893 [03:01<52:54,  3.79s/it]  The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   6%|▋         | 56/893 [03:02<42:25,  3.04s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   6%|▋         | 57/893 [03:04<36:15,  2.60s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   6%|▋         | 58/893 [03:06<32:49,  2.36s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   7%|▋         | 59/893 [03:07<27:20,  1.97s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   7%|▋         | 60/893 [03:08<24:07,  1.74s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   7%|▋         | 61/893 [03:09<21:29,  1.55s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   7%|▋         | 62/893 [03:11<22:37,  1.63s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   7%|▋         | 63/893 [03:28<1:28:32,  6.40s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   7%|▋         | 64/893 [03:30<1:07:41,  4.90s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   7%|▋         | 65/893 [03:32<54:54,  3.98s/it]  The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   7%|▋         | 66/893 [03:37<1:02:40,  4.55s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   8%|▊         | 67/893 [03:39<49:35,  3.60s/it]  The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   8%|▊         | 68/893 [03:40<39:35,  2.88s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   8%|▊         | 69/893 [03:42<35:14,  2.57s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   8%|▊         | 70/893 [03:43<31:07,  2.27s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   8%|▊         | 71/893 [03:54<1:05:03,  4.75s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   8%|▊         | 72/893 [04:06<1:33:06,  6.80s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   8%|▊         | 73/893 [04:21<2:09:56,  9.51s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   8%|▊         | 74/893 [04:23<1:38:14,  7.20s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   8%|▊         | 75/893 [04:25<1:16:13,  5.59s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   9%|▊         | 76/893 [04:27<1:01:07,  4.49s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   9%|▊         | 77/893 [04:29<50:12,  3.69s/it]  The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   9%|▊         | 78/893 [04:31<42:11,  3.11s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   9%|▉         | 79/893 [04:32<36:46,  2.71s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   9%|▉         | 80/893 [04:34<33:13,  2.45s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   9%|▉         | 81/893 [04:36<30:40,  2.27s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   9%|▉         | 82/893 [04:37<26:11,  1.94s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   9%|▉         | 83/893 [04:39<25:25,  1.88s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:   9%|▉         | 84/893 [04:45<42:48,  3.17s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  10%|▉         | 85/893 [04:49<45:28,  3.38s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  10%|▉         | 86/893 [04:50<36:25,  2.71s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  10%|▉         | 87/893 [04:51<30:09,  2.25s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  10%|▉         | 88/893 [04:57<44:44,  3.34s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  10%|▉         | 89/893 [04:59<38:41,  2.89s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  10%|█         | 90/893 [05:02<39:09,  2.93s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  10%|█         | 91/893 [05:04<34:47,  2.60s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  10%|█         | 92/893 [05:06<31:41,  2.37s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  10%|█         | 93/893 [05:07<26:52,  2.02s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  11%|█         | 94/893 [05:08<23:13,  1.74s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  11%|█         | 95/893 [05:09<21:08,  1.59s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  11%|█         | 96/893 [05:11<22:24,  1.69s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  11%|█         | 97/893 [05:12<20:31,  1.55s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  11%|█         | 98/893 [05:26<1:07:14,  5.08s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  11%|█         | 99/893 [05:27<52:01,  3.93s/it]  The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  11%|█         | 100/893 [05:35<1:07:04,  5.07s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  11%|█▏        | 101/893 [05:36<54:00,  4.09s/it]  The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  11%|█▏        | 102/893 [05:38<45:22,  3.44s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  12%|█▏        | 103/893 [05:48<1:09:16,  5.26s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  12%|█▏        | 104/893 [05:49<53:14,  4.05s/it]  The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  12%|█▏        | 105/893 [05:50<41:35,  3.17s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  12%|█▏        | 106/893 [05:55<46:42,  3.56s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  12%|█▏        | 107/893 [05:56<37:13,  2.84s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  12%|█▏        | 108/893 [05:57<30:17,  2.32s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  12%|█▏        | 109/893 [05:58<25:31,  1.95s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  12%|█▏        | 110/893 [05:59<22:30,  1.72s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  12%|█▏        | 111/893 [06:01<22:55,  1.76s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  13%|█▎        | 112/893 [06:02<20:32,  1.58s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  13%|█▎        | 113/893 [06:03<18:50,  1.45s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  13%|█▎        | 114/893 [06:09<34:56,  2.69s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  13%|█▎        | 115/893 [06:11<31:15,  2.41s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  13%|█▎        | 116/893 [06:24<1:13:50,  5.70s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  13%|█▎        | 117/893 [06:25<56:16,  4.35s/it]  The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  13%|█▎        | 118/893 [06:34<1:11:36,  5.54s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  13%|█▎        | 119/893 [06:41<1:19:14,  6.14s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  13%|█▎        | 120/893 [06:43<1:02:33,  4.86s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  14%|█▎        | 121/893 [06:47<57:45,  4.49s/it]  The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  14%|█▎        | 122/893 [06:48<45:44,  3.56s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  14%|█▍        | 123/893 [06:49<36:33,  2.85s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  14%|█▍        | 124/893 [06:50<30:04,  2.35s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  14%|█▍        | 125/893 [06:52<25:36,  2.00s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  14%|█▍        | 126/893 [06:53<22:21,  1.75s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  14%|█▍        | 127/893 [06:55<22:38,  1.77s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  14%|█▍        | 128/893 [06:56<21:43,  1.70s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  14%|█▍        | 129/893 [06:57<19:36,  1.54s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  15%|█▍        | 130/893 [07:03<34:28,  2.71s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  15%|█▍        | 131/893 [07:08<44:50,  3.53s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  15%|█▍        | 132/893 [07:14<52:03,  4.10s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  15%|█▍        | 133/893 [07:29<1:34:30,  7.46s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  15%|█▌        | 134/893 [07:47<2:12:53, 10.51s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  15%|█▌        | 135/893 [07:59<2:20:40, 11.14s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  15%|█▌        | 136/893 [08:15<2:39:37, 12.65s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  15%|█▌        | 137/893 [08:17<1:58:34,  9.41s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  15%|█▌        | 138/893 [08:19<1:29:41,  7.13s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  16%|█▌        | 139/893 [08:21<1:09:25,  5.53s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  16%|█▌        | 140/893 [08:23<55:27,  4.42s/it]  The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  16%|█▌        | 141/893 [08:24<43:32,  3.47s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  16%|█▌        | 142/893 [08:25<36:06,  2.88s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  16%|█▌        | 143/893 [08:33<52:35,  4.21s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  16%|█▌        | 144/893 [08:35<43:41,  3.50s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  16%|█▌        | 145/893 [08:36<37:16,  2.99s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  16%|█▋        | 146/893 [08:38<33:15,  2.67s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  16%|█▋        | 147/893 [08:40<30:23,  2.44s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  17%|█▋        | 148/893 [08:47<46:16,  3.73s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  17%|█▋        | 149/893 [08:48<38:12,  3.08s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  17%|█▋        | 150/893 [08:52<40:27,  3.27s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  17%|█▋        | 151/893 [08:54<35:24,  2.86s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  17%|█▋        | 152/893 [08:55<29:40,  2.40s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  17%|█▋        | 153/893 [08:57<26:34,  2.16s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  17%|█▋        | 154/893 [08:59<25:02,  2.03s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  17%|█▋        | 155/893 [09:06<44:44,  3.64s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  17%|█▋        | 156/893 [09:11<48:31,  3.95s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  18%|█▊        | 157/893 [09:18<1:00:16,  4.91s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  18%|█▊        | 158/893 [09:25<1:08:54,  5.62s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  18%|█▊        | 159/893 [09:26<52:26,  4.29s/it]  The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  18%|█▊        | 160/893 [09:28<42:05,  3.45s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  18%|█▊        | 161/893 [09:30<36:29,  2.99s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  18%|█▊        | 162/893 [09:43<1:12:02,  5.91s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  18%|█▊        | 163/893 [09:47<1:08:17,  5.61s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  18%|█▊        | 164/893 [09:49<54:46,  4.51s/it]  The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  18%|█▊        | 165/893 [09:51<44:59,  3.71s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  19%|█▊        | 166/893 [09:53<36:09,  2.98s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  19%|█▊        | 167/893 [10:00<52:52,  4.37s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  19%|█▉        | 168/893 [10:08<1:05:30,  5.42s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  19%|█▉        | 169/893 [10:09<50:51,  4.21s/it]  The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  19%|█▉        | 170/893 [10:12<46:18,  3.84s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  19%|█▉        | 171/893 [10:15<40:59,  3.41s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  19%|█▉        | 172/893 [10:16<32:46,  2.73s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  19%|█▉        | 173/893 [10:23<47:17,  3.94s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  19%|█▉        | 174/893 [10:29<57:22,  4.79s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  20%|█▉        | 175/893 [10:34<56:30,  4.72s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  20%|█▉        | 176/893 [10:35<43:31,  3.64s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  20%|█▉        | 177/893 [10:42<53:24,  4.48s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  20%|█▉        | 178/893 [10:51<1:09:47,  5.86s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  20%|██        | 179/893 [10:52<52:17,  4.39s/it]  The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  20%|██        | 180/893 [10:53<41:50,  3.52s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  20%|██        | 181/893 [11:04<1:08:30,  5.77s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  20%|██        | 182/893 [11:06<54:30,  4.60s/it]  The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  20%|██        | 183/893 [11:12<1:01:05,  5.16s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  21%|██        | 184/893 [11:14<49:31,  4.19s/it]  The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  21%|██        | 185/893 [11:16<40:55,  3.47s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  21%|██        | 186/893 [11:20<42:02,  3.57s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  21%|██        | 187/893 [11:25<46:57,  3.99s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  21%|██        | 188/893 [11:30<49:03,  4.17s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  21%|██        | 189/893 [11:33<46:40,  3.98s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  21%|██▏       | 190/893 [11:40<57:28,  4.91s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  21%|██▏       | 191/893 [11:47<1:04:55,  5.55s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  22%|██▏       | 192/893 [11:48<49:56,  4.27s/it]  The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  22%|██▏       | 193/893 [11:51<43:04,  3.69s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  22%|██▏       | 194/893 [11:52<34:31,  2.96s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  22%|██▏       | 195/893 [12:00<50:28,  4.34s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  22%|██▏       | 196/893 [12:01<39:41,  3.42s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  22%|██▏       | 197/893 [12:02<32:08,  2.77s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  22%|██▏       | 198/893 [12:03<26:38,  2.30s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  22%|██▏       | 199/893 [12:15<58:52,  5.09s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  22%|██▏       | 200/893 [12:16<44:50,  3.88s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  23%|██▎       | 201/893 [12:21<48:46,  4.23s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  23%|██▎       | 202/893 [12:24<43:49,  3.81s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  23%|██▎       | 203/893 [12:28<44:46,  3.89s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  23%|██▎       | 204/893 [12:32<45:24,  3.95s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  23%|██▎       | 205/893 [12:36<45:50,  4.00s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  23%|██▎       | 206/893 [12:47<1:07:53,  5.93s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  23%|██▎       | 207/893 [12:57<1:23:13,  7.28s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  23%|██▎       | 208/893 [13:07<1:33:50,  8.22s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  23%|██▎       | 209/893 [13:20<1:48:40,  9.53s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  24%|██▎       | 210/893 [13:33<1:59:00, 10.45s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  24%|██▎       | 211/893 [13:45<2:06:09, 11.10s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  24%|██▎       | 212/893 [13:47<1:32:26,  8.14s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  24%|██▍       | 213/893 [13:55<1:34:27,  8.33s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  24%|██▍       | 214/893 [13:56<1:09:59,  6.18s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  24%|██▍       | 215/893 [13:58<52:38,  4.66s/it]  The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  24%|██▍       | 216/893 [14:00<44:43,  3.96s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  24%|██▍       | 217/893 [14:01<34:56,  3.10s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  24%|██▍       | 218/893 [14:02<28:23,  2.52s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  25%|██▍       | 219/893 [14:07<36:26,  3.24s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  25%|██▍       | 220/893 [14:09<32:19,  2.88s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  25%|██▍       | 221/893 [14:10<26:09,  2.34s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  25%|██▍       | 222/893 [14:12<24:10,  2.16s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  25%|██▍       | 223/893 [14:14<22:45,  2.04s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  25%|██▌       | 224/893 [14:17<28:35,  2.56s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  25%|██▌       | 225/893 [14:21<30:04,  2.70s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  25%|██▌       | 226/893 [14:27<42:57,  3.86s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  25%|██▌       | 227/893 [14:28<34:33,  3.11s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  26%|██▌       | 228/893 [14:30<27:38,  2.49s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  26%|██▌       | 229/893 [14:31<23:08,  2.09s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  26%|██▌       | 230/893 [14:33<24:37,  2.23s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  26%|██▌       | 231/893 [14:36<26:14,  2.38s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  26%|██▌       | 232/893 [14:37<22:49,  2.07s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  26%|██▌       | 233/893 [14:39<22:03,  2.01s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  26%|██▌       | 234/893 [14:41<21:30,  1.96s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# ...
# OLMO RAG:  91%|█████████▏| 815/893 [52:41<02:01,  1.55s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  91%|█████████▏| 816/893 [52:42<01:43,  1.34s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  91%|█████████▏| 817/893 [52:43<01:38,  1.29s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  92%|█████████▏| 818/893 [52:57<06:17,  5.03s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  92%|█████████▏| 819/893 [53:07<08:02,  6.52s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  92%|█████████▏| 820/893 [53:13<07:46,  6.39s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  92%|█████████▏| 821/893 [53:26<10:05,  8.41s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  92%|█████████▏| 822/893 [53:27<07:11,  6.07s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  92%|█████████▏| 823/893 [53:28<05:10,  4.43s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  92%|█████████▏| 824/893 [53:28<03:46,  3.28s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  92%|█████████▏| 825/893 [53:29<02:58,  2.62s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  92%|█████████▏| 826/893 [53:31<02:38,  2.37s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  93%|█████████▎| 827/893 [53:32<02:02,  1.86s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  93%|█████████▎| 828/893 [53:33<01:43,  1.60s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  93%|█████████▎| 829/893 [53:35<02:05,  1.96s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  93%|█████████▎| 830/893 [53:36<01:37,  1.55s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  93%|█████████▎| 831/893 [53:38<01:51,  1.80s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  93%|█████████▎| 832/893 [53:39<01:33,  1.54s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  93%|█████████▎| 833/893 [53:40<01:24,  1.41s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  93%|█████████▎| 834/893 [53:42<01:18,  1.33s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  94%|█████████▎| 835/893 [53:47<02:30,  2.59s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  94%|█████████▎| 836/893 [53:49<02:14,  2.37s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  94%|█████████▎| 837/893 [53:54<02:54,  3.11s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  94%|█████████▍| 838/893 [53:58<03:05,  3.37s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  94%|█████████▍| 839/893 [54:03<03:24,  3.78s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  94%|█████████▍| 840/893 [54:03<02:32,  2.87s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  94%|█████████▍| 841/893 [54:04<01:59,  2.30s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  94%|█████████▍| 842/893 [54:16<04:17,  5.04s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  94%|█████████▍| 843/893 [54:16<03:05,  3.72s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  95%|█████████▍| 844/893 [54:18<02:34,  3.15s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  95%|█████████▍| 845/893 [54:23<02:57,  3.71s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  95%|█████████▍| 846/893 [54:24<02:13,  2.85s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  95%|█████████▍| 847/893 [54:26<01:58,  2.57s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  95%|█████████▍| 848/893 [54:37<03:43,  4.97s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  95%|█████████▌| 849/893 [54:37<02:41,  3.66s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  95%|█████████▌| 850/893 [54:38<02:01,  2.83s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  95%|█████████▌| 851/893 [54:50<03:49,  5.47s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  95%|█████████▌| 852/893 [54:58<04:18,  6.29s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  96%|█████████▌| 853/893 [54:59<03:05,  4.64s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  96%|█████████▌| 854/893 [55:05<03:24,  5.24s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  96%|█████████▌| 855/893 [55:06<02:29,  3.94s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  96%|█████████▌| 856/893 [55:10<02:24,  3.91s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  96%|█████████▌| 857/893 [55:11<01:53,  3.16s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  96%|█████████▌| 858/893 [55:12<01:27,  2.50s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  96%|█████████▌| 859/893 [55:13<01:08,  2.00s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  96%|█████████▋| 860/893 [55:15<00:58,  1.78s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  96%|█████████▋| 861/893 [55:17<01:08,  2.14s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  97%|█████████▋| 862/893 [55:19<00:57,  1.84s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  97%|█████████▋| 863/893 [55:20<00:49,  1.65s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  97%|█████████▋| 864/893 [55:24<01:06,  2.30s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  97%|█████████▋| 865/893 [55:25<01:00,  2.15s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  97%|█████████▋| 866/893 [55:34<01:49,  4.07s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  97%|█████████▋| 867/893 [55:36<01:28,  3.40s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  97%|█████████▋| 868/893 [55:37<01:08,  2.74s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  97%|█████████▋| 869/893 [55:38<00:55,  2.33s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  97%|█████████▋| 870/893 [55:40<00:47,  2.07s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  98%|█████████▊| 871/893 [55:41<00:38,  1.74s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  98%|█████████▊| 872/893 [55:42<00:34,  1.63s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  98%|█████████▊| 873/893 [55:44<00:33,  1.69s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  98%|█████████▊| 874/893 [55:45<00:29,  1.55s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  98%|█████████▊| 875/893 [55:46<00:23,  1.33s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  98%|█████████▊| 876/893 [55:47<00:20,  1.22s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  98%|█████████▊| 877/893 [55:49<00:22,  1.43s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  98%|█████████▊| 878/893 [55:50<00:20,  1.35s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  98%|█████████▊| 879/893 [55:51<00:18,  1.34s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  99%|█████████▊| 880/893 [55:52<00:14,  1.12s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  99%|█████████▊| 881/893 [55:54<00:14,  1.25s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  99%|█████████▉| 882/893 [56:04<00:42,  3.88s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  99%|█████████▉| 883/893 [56:13<00:54,  5.47s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  99%|█████████▉| 884/893 [56:15<00:39,  4.41s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  99%|█████████▉| 885/893 [56:16<00:27,  3.48s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  99%|█████████▉| 886/893 [56:17<00:19,  2.77s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  99%|█████████▉| 887/893 [56:38<00:48,  8.14s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG:  99%|█████████▉| 888/893 [56:39<00:29,  5.98s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG: 100%|█████████▉| 889/893 [56:40<00:17,  4.47s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG: 100%|█████████▉| 890/893 [56:45<00:13,  4.58s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG: 100%|█████████▉| 891/893 [56:46<00:07,  3.79s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG: 100%|█████████▉| 892/893 [56:50<00:03,  3.57s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG: 100%|██████████| 893/893 [56:51<00:00,  3.82s/it]
# ✅ Done with olmo. Results saved to chatbot_result/rag_original/scenario_D_rag_original_results_olmo.csv

# %%
# === Config ===
scenario_no = "D"
scenario    = "rag_original"  
DEVICE = "cuda"
MODELS = {
    "llama":    "meta-llama/Llama-3.2-1B",
    "qwen":     "Qwen/Qwen3-0.6B-Base",
    "olmo":     "allenai/OLMo-2-0425-1B",
}

BERTSCORE_MODEL = "microsoft/deberta-base-mnli"  # fast & solid for FAQ/QA

# Output folder
OUT_DIR = "Evaluation"
os.makedirs(OUT_DIR, exist_ok=True)

# BLEU smoothing (method4 is friendlier for short answers)
smooth_fn = SmoothingFunction().method4
# Cache rouge scorer once
rouge = rouge_scorer.RougeScorer(["rougeL"], use_stemmer=True)

# === Helpers ===
def _safe_text(x):
    return "" if x is None or (isinstance(x, float) and math.isnan(x)) else str(x)

def normalize(text: str) -> list[str]:
    text = _safe_text(text).lower().translate(str.maketrans('', '', string.punctuation))
    return wordpunct_tokenize(text)

# def exact_match(pred: str, gold: str) -> int:
#     return int(_safe_text(pred).strip().lower() == _safe_text(gold).strip().lower())

def f1_score_overlap(pred: str, gold: str) -> float:
    pred_tokens = normalize(pred)
    gold_tokens = normalize(gold)
    if not pred_tokens or not gold_tokens:
        return 0.0
    common = Counter(pred_tokens) & Counter(gold_tokens)
    num_same = sum(common.values())
    if num_same == 0:
        return 0.0
    precision = num_same / len(pred_tokens)
    recall = num_same / len(gold_tokens)
    return 2 * precision * recall / (precision + recall)

def bleu_score(pred: str, gold: str) -> float:
    # BLEU-2 is fairer for short FAQ answers
    return sentence_bleu(
        [normalize(gold)], normalize(pred),
        weights=(0.5, 0.5, 0, 0),
        smoothing_function=smooth_fn
    )

def rouge_l_score(pred: str, gold: str) -> float:
    return rouge.score(_safe_text(gold), _safe_text(pred))["rougeL"].fmeasure

def meteor(pred: str, gold: str) -> float:
    return meteor_score([normalize(gold)], normalize(pred))

def clean_text(t: str) -> str:
    t = _safe_text(t).strip()
    for pre in ("answer:", "response:", "reply:"):
        if t.lower().startswith(pre):
            t = t[len(pre):].strip()
    return t.strip("`").strip()

def compute_metrics(preds_raw, golds_raw):
    preds = [clean_text(p) for p in preds_raw]
    golds = [clean_text(g) for g in golds_raw]

    # em_list, f1_list, bleu_list, rouge_list, meteor_list = [], [], [], [], []
    f1_list, bleu_list, rouge_list, meteor_list = [], [], [], []
    for pred, gold in zip(preds, golds):
        # em_list.append(exact_match(pred, gold))
        f1_list.append(f1_score_overlap(pred, gold))
        bleu_list.append(bleu_score(pred, gold))
        rouge_list.append(rouge_l_score(pred, gold))
        meteor_list.append(meteor(pred, gold))

    # BERTScore on CUDA; drop empty pairs to avoid warnings
    mask = [bool(p.strip()) and bool(g.strip()) for p, g in zip(preds, golds)]
    preds_nz = [p for p, m in zip(preds, mask) if m]
    golds_nz = [g for g, m in zip(golds, mask) if m]
    if len(preds_nz) == 0:
        bert_f1_avg = 0.0
    else:
        P, R, F1 = bertscore(
            preds_nz, golds_nz,
            lang="en",
            model_type=BERTSCORE_MODEL,
            rescale_with_baseline=True,
            device=DEVICE
        )
        bert_f1_avg = float(F1.mean()) * 100.0

    n = max(1, len(f1_list))
    metrics = [
        # "Exact Match", 
        "F1-overlap", "BLEU", "ROUGE-L", "METEOR", "BERTScore-F1"]
    scores = [
        # round(sum(em_list) / n * 100, 2),
        round(sum(f1_list) / n * 100, 2),
        round(sum(bleu_list) / n * 100, 2),
        round(sum(rouge_list) / n * 100, 2),
        round(sum(meteor_list) / n * 100, 2),
        round(bert_f1_avg, 2),
    ]
    assert len(metrics) == len(scores), f"metrics={len(metrics)} scores={len(scores)}"

    rows = [{"Metric": m, "Score": s} for m, s in zip(metrics, scores)]
    return pl.DataFrame(rows)

# === Run all models and combine outputs ===
all_summaries = []

for key, MODEL_NAME in MODELS.items():
    OUTPUT_CSV = f"chatbot_result/{scenario}/scenario_{scenario_no}_{scenario}_results_{key}.csv"

    print(f"\n🚀 Running Evaluation for: {MODEL_NAME}")

    result_df = pl.read_csv(OUTPUT_CSV)
    preds = result_df["prediction"].to_list()
    golds = result_df["response"].to_list()

    summary = compute_metrics(preds, golds).with_columns(pl.lit(key).alias("Model"))
    all_summaries.append(summary)

# Combine all models (long)
if all_summaries:
    final_df = pl.concat(all_summaries).select(["Model", "Metric", "Score"])
    final_df.write_csv(os.path.join(OUT_DIR, f"Scenario_{scenario_no}_Evaluation_AllModels.csv"))

    # Pivot for side-by-side comparison
    pivot_df = final_df.pivot(index="Metric", columns="Model", values="Score")
    pivot_df.write_csv(os.path.join(OUT_DIR, f"Scenario_{scenario_no}_Evaluation_Pivot.csv"))

    print("\n📊 Combined (pivot) comparison:")
    print(pivot_df)
    print("\n✅ Saved under 'Evaluation/'")
    print(f"- Scenario_{scenario_no}_Evaluation_AllModels.csv")
    print(f"- Scenario_{scenario_no}_Evaluation_Pivot.csv")
else:
    print("⚠️ No model results were processed.")
# Out:
# 🚀 Running Evaluation for: meta-llama/Llama-3.2-1B
#
# 🚀 Running Evaluation for: Qwen/Qwen3-0.6B-Base
#
# 🚀 Running Evaluation for: allenai/OLMo-2-0425-1B
#
# 📊 Combined (pivot) comparison:
# shape: (5, 4)
# ┌──────────────┬───────┬───────┬───────┐
# │ Metric       ┆ llama ┆ qwen  ┆ olmo  │
# │ ---          ┆ ---   ┆ ---   ┆ ---   │
# │ str          ┆ f64   ┆ f64   ┆ f64   │
# ╞══════════════╪═══════╪═══════╪═══════╡
# │ F1-overlap   ┆ 23.75 ┆ 38.66 ┆ 13.85 │
# │ BLEU         ┆ 6.21  ┆ 16.53 ┆ 4.15  │
# │ ROUGE-L      ┆ 16.14 ┆ 24.87 ┆ 9.34  │
# │ METEOR       ┆ 13.31 ┆ 26.29 ┆ 8.04  │
# │ BERTScore-F1 ┆ 18.77 ┆ 28.51 ┆ 25.48 │
# └──────────────┴───────┴───────┴───────┘
#
# ✅ Saved under 'Evaluation/'
# - Scenario_D_Evaluation_AllModels.csv
# - Scenario_D_Evaluation_Pivot.csv
# /tmp/ipykernel_7861/3556513291.py:134: DeprecationWarning: the argument `columns` for `DataFrame.pivot` is deprecated. It was renamed to `on` in version 1.0.0.
#   pivot_df = final_df.pivot(index="Metric", columns="Model", values="Score")
