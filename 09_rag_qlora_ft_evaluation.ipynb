# %%
import polars as pl
import os, math, string
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline
from peft import PeftModel
from transformers import BitsAndBytesConfig
import torch
import gc
from tqdm import tqdm
import numpy as np
import markdown

import lancedb
import nltk
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
from nltk.translate.meteor_score import meteor_score
from nltk.tokenize import word_tokenize, wordpunct_tokenize
from rouge_score import rouge_scorer
from bert_score import score as bertscore
from collections import Counter
import string
import random
import emoji

# === NLTK SETUP ===
nltk.download('punkt_tab')
nltk.download("wordnet")
smooth_fn = SmoothingFunction().method4
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/zorin17/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/zorin17/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
from huggingface_hub import login

# Insert your token here
login(token="")

# %%
gc.collect()
torch.cuda.empty_cache()
torch.cuda.ipc_collect()

# %%
df = pl.read_csv('hf://datasets/bitext/Bitext-customer-support-llm-chatbot-training-dataset/Bitext_Sample_Customer_Support_Training_Dataset_27K_responses-v11.csv')
# Data cleaning
# fill in null
df = df.with_columns([
    pl.col("instruction")
      .cast(str)
      .str.to_lowercase()
      .fill_null(""),
    
    pl.col("response")
      .cast(str)
      .str.to_lowercase()
      .fill_null(""),
    
    pl.col("intent")
      .cast(str)
      .fill_null("unknown")
])

# Remove emoji
def remove_emojis(text: str) -> str:
    return emoji.replace_emoji(text, replace="")  # Remove all emojis safely

# Apply to instruction and response
df = df.with_columns([
    pl.col("instruction").map_elements(remove_emojis).alias("instruction")
])

df = df.with_columns([
    pl.col("response").map_elements(remove_emojis).alias("response")
])

#Exclude noisy flags
# Filter out rows where 'flags' contains Z, Q, or W ===
flag = ["flags"]
df_z = df.filter(
    ~pl.col(flag).cast(str).str.contains("Z")
)

df_zw = df.filter(
    ~pl.col(flag).cast(str).str.contains("Z") &
    ~pl.col(flag).cast(str).str.contains("W")
)

df_clean = df.filter(
    ~pl.col(flag).cast(str).str.contains("Z") &
    ~pl.col(flag).cast(str).str.contains("W") &
    ~pl.col(flag).cast(str).str.contains("Q")
)

print(df_z.height)
print(df_zw.height)
print(df_clean.height)

category_counts = (
    df_clean
    .group_by("category")
    .agg(pl.count().alias("counts"))
    .sort("counts", descending=True)
)

print(category_counts)

# Filter only selected categories
selected_categories = ["ORDER", "REFUND", "SHIPPING", "DELIVERY"]
df_selected = df_clean.filter(
    pl.col("category").is_in(selected_categories)
)
# Out:
# /tmp/ipykernel_13172/777344230.py:25: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns([
# /tmp/ipykernel_13172/777344230.py:29: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns([
# 21586
# 20517
# 14454
# shape: (11, 2)
# ┌──────────────┬────────┐
# │ category     ┆ counts │
# │ ---          ┆ ---    │
# │ str          ┆ u32    │
# ╞══════════════╪════════╡
# │ ACCOUNT      ┆ 3251   │
# │ ORDER        ┆ 2152   │
# │ REFUND       ┆ 1527   │
# │ SHIPPING     ┆ 1156   │
# │ DELIVERY     ┆ 1102   │
# │ …            ┆ …      │
# │ INVOICE      ┆ 1076   │
# │ PAYMENT      ┆ 1028   │
# │ FEEDBACK     ┆ 1004   │
# │ CANCEL       ┆ 539    │
# │ SUBSCRIPTION ┆ 537    │
# └──────────────┴────────┘
# /tmp/ipykernel_13172/777344230.py:58: DeprecationWarning: `pl.count()` is deprecated. Please use `pl.len()` instead.
# (Deprecated in version 0.20.5)
#   .agg(pl.count().alias("counts"))

# %%
# Split dataset by category
# === Configuration ===
LABEL_COL = "category"  # 🔁 Replace with "intent" or any stratification column
SPLIT_RATIO_TRAIN = 0.7
SPLIT_RATIO_VAL = 0.15
SEED = 123
df_final = df_selected.clone()

# === Stratified split logic ===
random.seed(SEED)
train_parts = []
test_parts = []
val_parts = []

for label in df_final[LABEL_COL].unique().to_list():
    group_df = df_final.filter(pl.col(LABEL_COL) == label)
    group_df = group_df.sample(n=len(group_df), shuffle=True, seed=SEED)

    n = len(group_df)
    train_idx = int(n * SPLIT_RATIO_TRAIN)
    val_idx = int(n * (SPLIT_RATIO_TRAIN + SPLIT_RATIO_VAL))

    train_parts.append(group_df[:train_idx])
    val_parts.append(group_df[train_idx:val_idx])
    test_parts.append(group_df[val_idx:])

# === Combine all groups
train_df = pl.concat(train_parts).sort(["category", "instruction"])
val_df = pl.concat(val_parts).sort(["category", "instruction"])
test_df = pl.concat(test_parts).sort(["category", "instruction"])

print("✅ Split sizes:")
print(f"Train: {len(train_df)}")
print(f"Val:   {len(val_df)}")
print(f"Test:  {len(test_df)}")

print("\n📊 Category distribution in test set:")
print(test_df.select([pl.col(LABEL_COL)]).to_series().value_counts())
# Out:
# ✅ Split sizes:
# Train: 4154
# Val:   890
# Test:  893
#
# 📊 Category distribution in test set:
# shape: (4, 2)
# ┌──────────┬───────┐
# │ category ┆ count │
# │ ---      ┆ ---   │
# │ str      ┆ u32   │
# ╞══════════╪═══════╡
# │ DELIVERY ┆ 166   │
# │ ORDER    ┆ 323   │
# │ REFUND   ┆ 230   │
# │ SHIPPING ┆ 174   │
# └──────────┴───────┘

# %%
# === Configuration ===
scenario_no = "E"
scenario    = "rag_qlora_ft"  

# QLoRA generators: base + adapter
MODELS = {
    # "llama": {
    #     "base":    "meta-llama/Llama-3.2-1B",
    #     "adapter": "qlora-outputs/Llama-3.2-1B-faq",
    # },
    # "qwen": {
    #     "base":    "Qwen/Qwen3-0.6B-Base",
    #     "adapter": "qlora-outputs/Qwen3-0.6B-Base-faq",
    # },
    "olmo": { 
        "base":    "allenai/OLMo-2-0425-1B",
        "adapter": "qlora-outputs/OLMo-2-0425-1B-faq",
    },
}

OFFLOAD_DIR = "./offload"
USE_CUDA = torch.cuda.is_available()
SAVE_EVERY = 20

# === Load test set (pre-split externally)
questions = test_df["instruction"].cast(str).to_list()
answers = test_df["response"].cast(str).to_list()

# ----------------- RAG pieces -----------------

# Read data from LanceDB table
def load_faq_table():
    db = lancedb.connect("/home/zorin17/Desktop/LLM/")
    return db.open_table("LANCEDB_FAQ")

table = load_faq_table()

# Search reranker
def search(query, table, top_k=5, category=None, intent=None):
    s = table.search(query).limit(top_k)
    if category:
        s = s.where(f"category = '{category}'")
    if intent:
        s = s.where(f"intent = '{intent}'")

    result = s.to_list()
    if not result:
        return "[Context 1]:\n(no relevant context found)\n"

    blocks = []
    for i, r in enumerate(result, 1):
        text = (r.get("text") or "").strip()
        # optional: guard against empty rows
        if not text:
            text = "(empty context)"
        blocks.append(f"[Context {i}]:\n{text}\n")
    return "\n".join(blocks)

# Prompt template (system + user with explicit sections)
base_prompt = """You are a helpful retail assistant. Your task is to answer the user question using provided contexts as the answer. 
You must make your response organized and structured.

User question: {}
Contexts:
{}
"""
custom_template = """{% if messages | selectattr('role','equalto','system') | list %}
System: {{ (messages | selectattr('role','equalto','system') | map(attribute='content') | list) | join('\\n') }}
{% endif %}
{% for m in messages %}
{% if m['role'] == 'user' -%}
User: {{ m['content'] }}
{% elif m['role'] == 'assistant' -%}
Assistant: {{ m['content'] }}
{% elif m['role'] == 'tool' -%}
Tool: {{ m['content'] }}
{% elif m['role'] == 'developer' -%}
System: {{ m['content'] }}
{% else -%}
{{ m['role']|capitalize }}: {{ m['content'] }}
{% endif -%}
{% endfor %}
Assistant:"""

# ----------------- RAG pieces End -----------------

# ----------------- Utilities -----------------
# === Safe append function
def append_to_csv(new_data: pl.DataFrame, path: str):
    if os.path.exists(path):
        existing = pl.read_csv(path)
        combined = existing.vstack(new_data)
    else:
        combined = new_data
    combined.write_csv(path)

def adaptive_max_new_tokens(gold_text: str, tokenizer, min_nt=48, max_nt=300, mult=1.3, bonus=16) -> int:
    n_gold = len(tokenizer(gold_text, add_special_tokens=False).input_ids)
    est = int(round(mult * n_gold) + bonus)
    return int(np.clip(est, min_nt, max_nt))

def _count_tokens(s, tok): 
    return len(tok(s, add_special_tokens=False).input_ids)

def safe_pack_contexts(question, contexts, tokenizer, max_src_tokens=700):
    head = "You are a helpful retail assistant. Your task is to answer the user question using provided contexts as the answer.\n\n"
    used = _count_tokens(head + f"User question: {question}\nContexts:\n", tokenizer)
    kept, buf = [], contexts.splitlines()
    for c in buf:
        block = c.strip() + "\n"
        t = _count_tokens(block, tokenizer)
        if used + t > max_src_tokens:
            break
        kept.append(block); used += t
    return "".join(kept)

def generate_one(tokenizer, hf_model, base_prompt, question, context,
                 temperature=0.0, max_new_tokens=128, return_html=False):
    system_content = base_prompt.format(question, context)
    messages = [
        {"role": "system", "content": system_content},
        {"role": "user",   "content": f"Question: {question}\n\nContext:\n{context}"}
    ]
    prompt = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True,
        chat_template=custom_template
    )
    inputs = tokenizer(prompt, return_tensors="pt").to(hf_model.device)
    input_len = inputs["input_ids"].shape[-1]

    with torch.inference_mode():
        outputs = hf_model.generate(
            **inputs,
            do_sample=(temperature > 0),
            temperature=temperature,
            top_p=0.95,
            max_new_tokens=max_new_tokens,
            no_repeat_ngram_size=3,
            eos_token_id=tokenizer.eos_token_id,
            pad_token_id=tokenizer.pad_token_id,
            return_dict_in_generate=True,
        )

    new_tokens = outputs.sequences[0, input_len:]
    text = tokenizer.decode(new_tokens, skip_special_tokens=True).strip()
    return markdown.markdown(text) if return_html else text

def rag_answer(tokenizer, hf_model, question, temperature=0.0, category=None, intent=None, max_new_tokens=128):
    raw_ctx = search(question, table, top_k=5, category=category, intent=intent)
    context = safe_pack_contexts(question, raw_ctx, tokenizer, max_src_tokens=700)
    return generate_one(tokenizer, hf_model, base_prompt, question, context,
                        temperature=temperature, max_new_tokens=max_new_tokens, return_html=False)

# === QLoRA loader ===
def load_tokenizer(model_or_path: str):
    tok = AutoTokenizer.from_pretrained(model_or_path, use_fast=True, trust_remote_code=True)
    if tok.pad_token is None:
        tok.pad_token = tok.eos_token
    tok.padding_side = "right"
    return tok

def load_base_4bit(base_name: str, offload_dir: str):
    supports_bf16 = torch.cuda.is_available() and torch.cuda.get_device_capability(0)[0] >= 8
    bnb = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_use_double_quant=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=torch.bfloat16 if supports_bf16 else torch.float16,
    )
    return AutoModelForCausalLM.from_pretrained(
        base_name,
        quantization_config=bnb,
        device_map="auto",
        attn_implementation="sdpa",
        torch_dtype=torch.bfloat16 if supports_bf16 else torch.float16,
        offload_folder=offload_dir,
        trust_remote_code=True,
    )

def enable_inference_cache(model):
    if getattr(model.config, "use_cache", None) is not True:
        model.config.use_cache = True

# ----------------- Run all QLoRA generators -----------------
for key, cfg in MODELS.items():
    BASE = cfg["base"]
    ADAPTER_DIR = cfg["adapter"]

    # sanity: adapter exists
    assert os.path.exists(ADAPTER_DIR), f"Adapter not found for {key}: {ADAPTER_DIR}"

    OUTPUT_CSV = f"chatbot_result/{scenario}/scenario_{scenario_no}_{scenario}_results_{key}.csv"
    print(f"\n🚀 Scenario {scenario_no} (RAG + QLoRA) — Inference for: {BASE} + {ADAPTER_DIR}")
    os.makedirs(os.path.dirname(OUTPUT_CSV), exist_ok=True)

    torch.cuda.empty_cache(); torch.cuda.ipc_collect()

    # --- Load base (4-bit) + attach LoRA adapter ---
    tokenizer = load_tokenizer(BASE)
    base_model = load_base_4bit(BASE, OFFLOAD_DIR)
    hf_model  = PeftModel.from_pretrained(base_model, ADAPTER_DIR)
    enable_inference_cache(hf_model)
    hf_model.eval()

    # resume
    if os.path.exists(OUTPUT_CSV):
        existing = pl.read_csv(OUTPUT_CSV)
        done = set(existing["instruction"].to_list())
        print(f"🔄 Resuming from {len(done)} rows...")
    else:
        done = set()

    results = []
    for question, gold in tqdm(zip(questions, answers), total=len(questions), desc=f"{key.upper()} RAG+FT"):
        if question in done:
            continue

        max_nt = adaptive_max_new_tokens(gold, tokenizer, min_nt=48, max_nt=300, mult=1.3, bonus=16)

        try:
            pred = rag_answer(
                tokenizer, hf_model, question,
                temperature=0.0,
                category=None, intent=None,
                max_new_tokens=max_nt
            )
            if "Assistant:" in pred:
                pred = pred.split("Assistant:")[-1].strip()

        except Exception as e:
            print(f"⚠️ Error on: {question[:60]}... Skip. Reason: {e}")
            continue

        results.append((question, gold, pred))

        if len(results) >= SAVE_EVERY:
            chunk_df = pl.DataFrame(results, schema=["instruction", "response", "prediction"])
            enriched = test_df.join(chunk_df, on=["instruction", "response"], how="inner")
            append_to_csv(enriched, OUTPUT_CSV)
            results = []

    if results:
        chunk_df = pl.DataFrame(results, schema=["instruction", "response", "prediction"])
        enriched = test_df.join(chunk_df, on=["instruction", "response"], how="inner")
        append_to_csv(enriched, OUTPUT_CSV)

    print(f"✅ Done with {key}. Results saved to {OUTPUT_CSV}")

    # cleanup VRAM
    del tokenizer, hf_model, base_model
    gc.collect()
    torch.cuda.empty_cache()
    torch.cuda.ipc_collect()
# Out:
# 🚀 Scenario E (RAG + QLoRA) — Inference for: allenai/OLMo-2-0425-1B + qlora-outputs/OLMo-2-0425-1B-faq
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# OLMO RAG+FT:   0%|          | 0/893 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   0%|          | 1/893 [00:08<2:06:48,  8.53s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   0%|          | 2/893 [00:13<1:35:40,  6.44s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   0%|          | 3/893 [00:24<2:07:09,  8.57s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   0%|          | 4/893 [00:31<1:56:44,  7.88s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   1%|          | 5/893 [00:34<1:28:48,  6.00s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   1%|          | 6/893 [00:42<1:38:58,  6.69s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   1%|          | 7/893 [00:48<1:36:23,  6.53s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   1%|          | 8/893 [00:55<1:36:58,  6.57s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   1%|          | 9/893 [01:00<1:32:41,  6.29s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   1%|          | 10/893 [01:04<1:20:38,  5.48s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   1%|          | 11/893 [01:10<1:23:52,  5.71s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   1%|▏         | 12/893 [01:15<1:19:30,  5.42s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   1%|▏         | 13/893 [01:21<1:23:09,  5.67s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   2%|▏         | 14/893 [01:28<1:27:02,  5.94s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   2%|▏         | 15/893 [01:38<1:48:35,  7.42s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   2%|▏         | 16/893 [01:46<1:47:16,  7.34s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   2%|▏         | 17/893 [01:52<1:41:34,  6.96s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   2%|▏         | 18/893 [01:56<1:30:45,  6.22s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   2%|▏         | 19/893 [02:01<1:23:39,  5.74s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# /home/zorin17/miniconda3/envs/llm/lib/python3.10/functools.py:889: DataOrientationWarning: Row orientation inferred during DataFrame construction. Explicitly specify the orientation by passing `orient="row"` to silence this warning.
#   return dispatch(args[0].__class__)(*args, **kw)
# OLMO RAG+FT:   2%|▏         | 20/893 [02:06<1:22:07,  5.64s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   2%|▏         | 21/893 [02:13<1:27:14,  6.00s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   2%|▏         | 22/893 [02:16<1:12:22,  4.99s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   3%|▎         | 23/893 [02:31<1:55:34,  7.97s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   3%|▎         | 24/893 [02:40<2:01:45,  8.41s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   3%|▎         | 25/893 [02:50<2:06:29,  8.74s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   3%|▎         | 26/893 [03:00<2:11:46,  9.12s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   3%|▎         | 27/893 [03:03<1:48:12,  7.50s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   3%|▎         | 28/893 [03:20<2:28:23, 10.29s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   3%|▎         | 29/893 [03:27<2:15:05,  9.38s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   3%|▎         | 30/893 [03:35<2:05:46,  8.74s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   3%|▎         | 31/893 [03:49<2:30:24, 10.47s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   4%|▎         | 32/893 [03:55<2:11:43,  9.18s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   4%|▎         | 33/893 [04:06<2:18:39,  9.67s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   4%|▍         | 34/893 [04:12<2:00:20,  8.41s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   4%|▍         | 35/893 [04:32<2:52:40, 12.07s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   4%|▍         | 36/893 [04:37<2:20:16,  9.82s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   4%|▍         | 37/893 [04:47<2:23:12, 10.04s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   4%|▍         | 38/893 [04:49<1:46:23,  7.47s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   4%|▍         | 39/893 [04:54<1:36:42,  6.79s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   4%|▍         | 40/893 [04:58<1:26:18,  6.07s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   5%|▍         | 41/893 [05:05<1:27:33,  6.17s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   5%|▍         | 42/893 [05:15<1:44:37,  7.38s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   5%|▍         | 43/893 [05:19<1:30:30,  6.39s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   5%|▍         | 44/893 [05:34<2:08:38,  9.09s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   5%|▌         | 45/893 [05:44<2:12:18,  9.36s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   5%|▌         | 46/893 [05:58<2:28:45, 10.54s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   5%|▌         | 47/893 [06:02<2:02:09,  8.66s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   5%|▌         | 48/893 [06:06<1:41:28,  7.21s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   5%|▌         | 49/893 [06:10<1:30:00,  6.40s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   6%|▌         | 50/893 [06:18<1:33:39,  6.67s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   6%|▌         | 51/893 [06:22<1:25:12,  6.07s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   6%|▌         | 52/893 [06:41<2:16:09,  9.71s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   6%|▌         | 53/893 [06:45<1:55:39,  8.26s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   6%|▌         | 54/893 [06:57<2:08:19,  9.18s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   6%|▌         | 55/893 [07:03<1:55:49,  8.29s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   6%|▋         | 56/893 [07:09<1:45:57,  7.60s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   6%|▋         | 57/893 [07:15<1:38:19,  7.06s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   6%|▋         | 58/893 [07:34<2:27:45, 10.62s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   7%|▋         | 59/893 [07:40<2:09:31,  9.32s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   7%|▋         | 60/893 [07:45<1:50:01,  7.92s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   7%|▋         | 61/893 [07:53<1:52:27,  8.11s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   7%|▋         | 62/893 [08:00<1:49:08,  7.88s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   7%|▋         | 63/893 [08:17<2:25:27, 10.52s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   7%|▋         | 64/893 [08:22<2:00:40,  8.73s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   7%|▋         | 65/893 [08:27<1:44:56,  7.61s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   7%|▋         | 66/893 [08:38<2:00:40,  8.76s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   8%|▊         | 67/893 [08:43<1:45:20,  7.65s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   8%|▊         | 68/893 [08:49<1:35:55,  6.98s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   8%|▊         | 69/893 [08:54<1:31:14,  6.64s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   8%|▊         | 70/893 [09:11<2:11:36,  9.60s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   8%|▊         | 71/893 [09:21<2:12:50,  9.70s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   8%|▊         | 72/893 [09:39<2:45:42, 12.11s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   8%|▊         | 73/893 [09:45<2:22:56, 10.46s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   8%|▊         | 74/893 [09:49<1:56:08,  8.51s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   8%|▊         | 75/893 [09:56<1:49:32,  8.04s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   9%|▊         | 76/893 [10:16<2:36:16, 11.48s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   9%|▊         | 77/893 [10:20<2:06:34,  9.31s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   9%|▊         | 78/893 [10:35<2:28:51, 10.96s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   9%|▉         | 79/893 [10:49<2:40:46, 11.85s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   9%|▉         | 80/893 [11:10<3:19:25, 14.72s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   9%|▉         | 81/893 [11:17<2:46:58, 12.34s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   9%|▉         | 82/893 [11:23<2:22:02, 10.51s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   9%|▉         | 83/893 [11:41<2:52:59, 12.81s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   9%|▉         | 84/893 [11:47<2:23:45, 10.66s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  10%|▉         | 85/893 [11:52<2:02:59,  9.13s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  10%|▉         | 86/893 [11:59<1:52:48,  8.39s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  10%|▉         | 87/893 [12:06<1:45:14,  7.83s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  10%|▉         | 88/893 [12:21<2:16:57, 10.21s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  10%|▉         | 89/893 [12:41<2:55:39, 13.11s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  10%|█         | 90/893 [12:48<2:31:07, 11.29s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  10%|█         | 91/893 [13:00<2:32:08, 11.38s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  10%|█         | 92/893 [13:12<2:32:45, 11.44s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  10%|█         | 93/893 [13:17<2:10:24,  9.78s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  11%|█         | 94/893 [13:23<1:55:08,  8.65s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  11%|█         | 95/893 [13:32<1:56:44,  8.78s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  11%|█         | 96/893 [13:38<1:42:21,  7.71s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  11%|█         | 97/893 [13:43<1:34:08,  7.10s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  11%|█         | 98/893 [13:49<1:28:09,  6.65s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  11%|█         | 99/893 [13:53<1:17:08,  5.83s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  11%|█         | 100/893 [14:09<1:57:40,  8.90s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  11%|█▏        | 101/893 [14:28<2:35:47, 11.80s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  11%|█▏        | 102/893 [14:34<2:13:03, 10.09s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  12%|█▏        | 103/893 [14:44<2:14:32, 10.22s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  12%|█▏        | 104/893 [14:50<1:56:29,  8.86s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  12%|█▏        | 105/893 [14:54<1:39:15,  7.56s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  12%|█▏        | 106/893 [14:58<1:25:33,  6.52s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  12%|█▏        | 107/893 [15:04<1:20:09,  6.12s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  12%|█▏        | 108/893 [15:10<1:19:24,  6.07s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  12%|█▏        | 109/893 [15:13<1:08:13,  5.22s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  12%|█▏        | 110/893 [15:19<1:12:28,  5.55s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  12%|█▏        | 111/893 [15:32<1:38:58,  7.59s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  13%|█▎        | 112/893 [15:38<1:35:37,  7.35s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  13%|█▎        | 113/893 [15:47<1:40:11,  7.71s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  13%|█▎        | 114/893 [16:00<2:01:36,  9.37s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  13%|█▎        | 115/893 [16:04<1:38:51,  7.62s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  13%|█▎        | 116/893 [16:18<2:05:29,  9.69s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  13%|█▎        | 117/893 [16:22<1:44:30,  8.08s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  13%|█▎        | 118/893 [16:27<1:30:55,  7.04s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  13%|█▎        | 119/893 [16:32<1:21:02,  6.28s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  13%|█▎        | 120/893 [16:43<1:40:32,  7.80s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  14%|█▎        | 121/893 [16:54<1:53:05,  8.79s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  14%|█▎        | 122/893 [17:01<1:44:09,  8.11s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  14%|█▍        | 123/893 [17:07<1:39:10,  7.73s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  14%|█▍        | 124/893 [17:15<1:36:50,  7.56s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  14%|█▍        | 125/893 [17:19<1:24:02,  6.57s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  14%|█▍        | 126/893 [17:28<1:32:07,  7.21s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  14%|█▍        | 127/893 [17:34<1:30:38,  7.10s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  14%|█▍        | 128/893 [17:39<1:21:37,  6.40s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  14%|█▍        | 129/893 [17:45<1:18:52,  6.19s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  15%|█▍        | 130/893 [17:52<1:21:53,  6.44s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  15%|█▍        | 131/893 [17:59<1:23:52,  6.60s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  15%|█▍        | 132/893 [18:06<1:25:11,  6.72s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  15%|█▍        | 133/893 [18:13<1:25:54,  6.78s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  15%|█▌        | 134/893 [18:20<1:26:31,  6.84s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  15%|█▌        | 135/893 [18:27<1:26:55,  6.88s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  15%|█▌        | 136/893 [18:34<1:27:05,  6.90s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  15%|█▌        | 137/893 [18:49<1:58:05,  9.37s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  15%|█▌        | 138/893 [18:56<1:49:41,  8.72s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  16%|█▌        | 139/893 [19:03<1:43:50,  8.26s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  16%|█▌        | 140/893 [19:20<2:15:10, 10.77s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  16%|█▌        | 141/893 [19:24<1:51:49,  8.92s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  16%|█▌        | 142/893 [19:31<1:41:21,  8.10s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  16%|█▌        | 143/893 [19:45<2:06:25, 10.11s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  16%|█▌        | 144/893 [19:53<1:55:39,  9.27s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  16%|█▌        | 145/893 [19:58<1:42:06,  8.19s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  16%|█▋        | 146/893 [20:06<1:39:59,  8.03s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  16%|█▋        | 147/893 [20:11<1:26:33,  6.96s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  17%|█▋        | 148/893 [20:15<1:16:07,  6.13s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  17%|█▋        | 149/893 [20:26<1:35:02,  7.66s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  17%|█▋        | 150/893 [20:35<1:40:00,  8.08s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  17%|█▋        | 151/893 [20:40<1:28:24,  7.15s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  17%|█▋        | 152/893 [20:46<1:23:40,  6.78s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  17%|█▋        | 153/893 [20:51<1:18:55,  6.40s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  17%|█▋        | 154/893 [21:05<1:46:18,  8.63s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  17%|█▋        | 155/893 [21:21<2:11:08, 10.66s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  17%|█▋        | 156/893 [21:31<2:11:31, 10.71s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  18%|█▊        | 157/893 [21:40<2:03:51, 10.10s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  18%|█▊        | 158/893 [21:47<1:51:59,  9.14s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  18%|█▊        | 159/893 [21:52<1:37:43,  7.99s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  18%|█▊        | 160/893 [22:00<1:36:14,  7.88s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  18%|█▊        | 161/893 [22:13<1:54:06,  9.35s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  18%|█▊        | 162/893 [22:24<1:59:08,  9.78s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  18%|█▊        | 163/893 [22:35<2:04:22, 10.22s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  18%|█▊        | 164/893 [22:47<2:09:48, 10.68s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  18%|█▊        | 165/893 [22:58<2:11:54, 10.87s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  19%|█▊        | 166/893 [23:03<1:50:01,  9.08s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  19%|█▊        | 167/893 [23:07<1:33:03,  7.69s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  19%|█▉        | 168/893 [23:11<1:18:58,  6.54s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  19%|█▉        | 169/893 [23:13<1:03:13,  5.24s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  19%|█▉        | 170/893 [23:18<1:02:21,  5.17s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  19%|█▉        | 171/893 [23:24<1:04:00,  5.32s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  19%|█▉        | 172/893 [23:30<1:07:07,  5.59s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  19%|█▉        | 173/893 [23:33<55:52,  4.66s/it]  The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  19%|█▉        | 174/893 [23:35<48:01,  4.01s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  20%|█▉        | 175/893 [23:39<46:30,  3.89s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  20%|█▉        | 176/893 [23:48<1:06:09,  5.54s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  20%|█▉        | 177/893 [23:56<1:15:36,  6.34s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  20%|█▉        | 178/893 [24:02<1:11:56,  6.04s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  20%|██        | 179/893 [24:08<1:11:52,  6.04s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  20%|██        | 180/893 [24:14<1:12:19,  6.09s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  20%|██        | 181/893 [24:16<59:08,  4.98s/it]  The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  20%|██        | 182/893 [24:23<1:05:47,  5.55s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  20%|██        | 183/893 [24:32<1:17:33,  6.55s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  21%|██        | 184/893 [24:42<1:27:51,  7.44s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  21%|██        | 185/893 [24:51<1:35:24,  8.09s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  21%|██        | 186/893 [24:56<1:25:08,  7.23s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  21%|██        | 187/893 [25:07<1:36:54,  8.24s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  21%|██        | 188/893 [25:10<1:20:04,  6.82s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  21%|██        | 189/893 [25:13<1:03:50,  5.44s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  21%|██▏       | 190/893 [25:29<1:41:28,  8.66s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  21%|██▏       | 191/893 [25:45<2:07:23, 10.89s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  22%|██▏       | 192/893 [25:55<2:05:51, 10.77s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  22%|██▏       | 193/893 [26:00<1:44:35,  8.97s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  22%|██▏       | 194/893 [26:08<1:41:14,  8.69s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  22%|██▏       | 195/893 [26:14<1:30:19,  7.76s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  22%|██▏       | 196/893 [26:19<1:22:38,  7.11s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  22%|██▏       | 197/893 [26:23<1:10:31,  6.08s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  22%|██▏       | 198/893 [26:31<1:17:00,  6.65s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  22%|██▏       | 199/893 [26:36<1:11:43,  6.20s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  22%|██▏       | 200/893 [26:40<1:04:16,  5.57s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  23%|██▎       | 201/893 [26:47<1:08:29,  5.94s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  23%|██▎       | 202/893 [26:54<1:12:20,  6.28s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  23%|██▎       | 203/893 [26:58<1:05:04,  5.66s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  23%|██▎       | 204/893 [27:03<1:00:00,  5.22s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  23%|██▎       | 205/893 [27:07<56:25,  4.92s/it]  The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  23%|██▎       | 206/893 [27:13<1:01:07,  5.34s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  23%|██▎       | 207/893 [27:18<1:00:40,  5.31s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  23%|██▎       | 208/893 [27:24<1:00:19,  5.28s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  23%|██▎       | 209/893 [27:30<1:05:19,  5.73s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  24%|██▎       | 210/893 [27:37<1:08:43,  6.04s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  24%|██▎       | 211/893 [27:44<1:11:05,  6.25s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  24%|██▎       | 212/893 [27:52<1:15:27,  6.65s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  24%|██▍       | 213/893 [27:55<1:05:55,  5.82s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  24%|██▍       | 214/893 [28:00<1:02:03,  5.48s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  24%|██▍       | 215/893 [28:03<54:27,  4.82s/it]  The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  24%|██▍       | 216/893 [28:09<57:20,  5.08s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  24%|██▍       | 217/893 [28:14<57:50,  5.13s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  24%|██▍       | 218/893 [28:18<52:03,  4.63s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  25%|██▍       | 219/893 [28:24<58:07,  5.17s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  25%|██▍       | 220/893 [28:30<1:00:25,  5.39s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  25%|██▍       | 221/893 [28:34<56:22,  5.03s/it]  The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  25%|██▍       | 222/893 [28:42<1:03:53,  5.71s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  25%|██▍       | 223/893 [28:49<1:09:16,  6.20s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  25%|██▌       | 224/893 [28:55<1:08:56,  6.18s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  25%|██▌       | 225/893 [29:02<1:09:42,  6.26s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  25%|██▌       | 226/893 [29:07<1:05:54,  5.93s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  25%|██▌       | 227/893 [29:12<1:05:01,  5.86s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  26%|██▌       | 228/893 [29:17<59:56,  5.41s/it]  The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  26%|██▌       | 229/893 [29:21<56:19,  5.09s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# ...
# OLMO RAG+FT:  91%|█████████▏| 817/893 [1:35:26<04:46,  3.77s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  92%|█████████▏| 818/893 [1:35:34<06:29,  5.19s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  92%|█████████▏| 819/893 [1:35:53<11:13,  9.10s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  92%|█████████▏| 820/893 [1:36:07<13:01, 10.70s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  92%|█████████▏| 821/893 [1:36:18<13:01, 10.86s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  92%|█████████▏| 822/893 [1:36:21<09:59,  8.45s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  92%|█████████▏| 823/893 [1:36:24<08:06,  6.95s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  92%|█████████▏| 824/893 [1:36:27<06:30,  5.67s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  92%|█████████▏| 825/893 [1:36:30<05:32,  4.89s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  92%|█████████▏| 826/893 [1:36:44<08:32,  7.64s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  93%|█████████▎| 827/893 [1:36:48<06:59,  6.36s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  93%|█████████▎| 828/893 [1:36:53<06:28,  5.97s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  93%|█████████▎| 829/893 [1:36:55<05:20,  5.01s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  93%|█████████▎| 830/893 [1:36:59<04:40,  4.45s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  93%|█████████▎| 831/893 [1:37:02<04:21,  4.22s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  93%|█████████▎| 832/893 [1:37:05<03:51,  3.80s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  93%|█████████▎| 833/893 [1:37:10<04:13,  4.23s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  93%|█████████▎| 834/893 [1:37:14<04:05,  4.17s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  94%|█████████▎| 835/893 [1:37:19<04:14,  4.39s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  94%|█████████▎| 836/893 [1:37:25<04:30,  4.75s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  94%|█████████▎| 837/893 [1:37:28<03:57,  4.25s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  94%|█████████▍| 838/893 [1:37:40<06:09,  6.71s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  94%|█████████▍| 839/893 [1:37:43<04:54,  5.46s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  94%|█████████▍| 840/893 [1:37:46<04:17,  4.87s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  94%|█████████▍| 841/893 [1:37:52<04:18,  4.96s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  94%|█████████▍| 842/893 [1:37:55<03:47,  4.46s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  94%|█████████▍| 843/893 [1:37:58<03:25,  4.11s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  95%|█████████▍| 844/893 [1:38:06<04:10,  5.11s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  95%|█████████▍| 845/893 [1:38:09<03:46,  4.73s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  95%|█████████▍| 846/893 [1:38:12<03:16,  4.18s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  95%|█████████▍| 847/893 [1:38:19<03:39,  4.77s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  95%|█████████▍| 848/893 [1:38:25<04:00,  5.34s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  95%|█████████▌| 849/893 [1:38:29<03:34,  4.87s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  95%|█████████▌| 850/893 [1:38:31<02:52,  4.00s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  95%|█████████▌| 851/893 [1:38:37<03:11,  4.56s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  95%|█████████▌| 852/893 [1:38:43<03:32,  5.17s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  96%|█████████▌| 853/893 [1:38:46<02:59,  4.50s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  96%|█████████▌| 854/893 [1:38:50<02:49,  4.34s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  96%|█████████▌| 855/893 [1:38:54<02:42,  4.26s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  96%|█████████▌| 856/893 [1:39:13<05:19,  8.63s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  96%|█████████▌| 857/893 [1:39:21<04:59,  8.31s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  96%|█████████▌| 858/893 [1:39:24<04:01,  6.91s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  96%|█████████▌| 859/893 [1:39:28<03:19,  5.87s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  96%|█████████▋| 860/893 [1:39:31<02:50,  5.17s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  96%|█████████▋| 861/893 [1:39:35<02:30,  4.70s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  97%|█████████▋| 862/893 [1:39:40<02:29,  4.82s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  97%|█████████▋| 863/893 [1:39:45<02:28,  4.97s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  97%|█████████▋| 864/893 [1:39:54<02:53,  5.97s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  97%|█████████▋| 865/893 [1:39:59<02:42,  5.82s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  97%|█████████▋| 866/893 [1:40:04<02:27,  5.45s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  97%|█████████▋| 867/893 [1:40:11<02:35,  5.98s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  97%|█████████▋| 868/893 [1:40:17<02:30,  6.03s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  97%|█████████▋| 869/893 [1:40:23<02:20,  5.84s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  97%|█████████▋| 870/893 [1:40:25<01:48,  4.73s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  98%|█████████▊| 871/893 [1:40:29<01:39,  4.54s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  98%|█████████▊| 872/893 [1:40:35<01:45,  5.00s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  98%|█████████▊| 873/893 [1:40:40<01:41,  5.09s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  98%|█████████▊| 874/893 [1:40:48<01:53,  5.97s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  98%|█████████▊| 875/893 [1:40:50<01:26,  4.83s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  98%|█████████▊| 876/893 [1:40:52<01:07,  3.98s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  98%|█████████▊| 877/893 [1:41:02<01:32,  5.80s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  98%|█████████▊| 878/893 [1:41:05<01:14,  4.96s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  98%|█████████▊| 879/893 [1:41:11<01:12,  5.17s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  99%|█████████▊| 880/893 [1:41:14<00:57,  4.41s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  99%|█████████▊| 881/893 [1:41:19<00:57,  4.82s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  99%|█████████▉| 882/893 [1:41:27<01:01,  5.63s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  99%|█████████▉| 883/893 [1:41:37<01:09,  6.98s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  99%|█████████▉| 884/893 [1:41:42<00:56,  6.26s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  99%|█████████▉| 885/893 [1:41:47<00:46,  5.84s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  99%|█████████▉| 886/893 [1:41:55<00:46,  6.67s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  99%|█████████▉| 887/893 [1:42:17<01:08, 11.34s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  99%|█████████▉| 888/893 [1:42:19<00:42,  8.53s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT: 100%|█████████▉| 889/893 [1:42:28<00:34,  8.59s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT: 100%|█████████▉| 890/893 [1:42:34<00:23,  7.92s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT: 100%|█████████▉| 891/893 [1:42:40<00:14,  7.30s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT: 100%|█████████▉| 892/893 [1:42:45<00:06,  6.67s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT: 100%|██████████| 893/893 [1:42:52<00:00,  6.91s/it]
# ✅ Done with olmo. Results saved to chatbot_result/rag_qlora_ft/scenario_E_rag_qlora_ft_results_olmo.csv

# %%
# === Config ===
scenario_no = "E"
scenario    = "rag_qlora_ft"  
DEVICE = "cuda"
MODELS = {
    "llama":    "meta-llama/Llama-3.2-1B",
    "qwen":     "Qwen/Qwen3-0.6B-Base",
    "olmo":     "allenai/OLMo-2-0425-1B",
}

BERTSCORE_MODEL = "microsoft/deberta-base-mnli"  # fast & solid for FAQ/QA

# Output folder
OUT_DIR = "Evaluation"
os.makedirs(OUT_DIR, exist_ok=True)

# BLEU smoothing (method4 is friendlier for short answers)
smooth_fn = SmoothingFunction().method4
# Cache rouge scorer once
rouge = rouge_scorer.RougeScorer(["rougeL"], use_stemmer=True)

# === Helpers ===
def _safe_text(x):
    return "" if x is None or (isinstance(x, float) and math.isnan(x)) else str(x)

def normalize(text: str) -> list[str]:
    text = _safe_text(text).lower().translate(str.maketrans('', '', string.punctuation))
    return wordpunct_tokenize(text)

# def exact_match(pred: str, gold: str) -> int:
#     return int(_safe_text(pred).strip().lower() == _safe_text(gold).strip().lower())

def f1_score_overlap(pred: str, gold: str) -> float:
    pred_tokens = normalize(pred)
    gold_tokens = normalize(gold)
    if not pred_tokens or not gold_tokens:
        return 0.0
    common = Counter(pred_tokens) & Counter(gold_tokens)
    num_same = sum(common.values())
    if num_same == 0:
        return 0.0
    precision = num_same / len(pred_tokens)
    recall = num_same / len(gold_tokens)
    return 2 * precision * recall / (precision + recall)

def bleu_score(pred: str, gold: str) -> float:
    # BLEU-2 is fairer for short FAQ answers
    return sentence_bleu(
        [normalize(gold)], normalize(pred),
        weights=(0.5, 0.5, 0, 0),
        smoothing_function=smooth_fn
    )

def rouge_l_score(pred: str, gold: str) -> float:
    return rouge.score(_safe_text(gold), _safe_text(pred))["rougeL"].fmeasure

def meteor(pred: str, gold: str) -> float:
    return meteor_score([normalize(gold)], normalize(pred))

def clean_text(t: str) -> str:
    t = _safe_text(t).strip()
    for pre in ("answer:", "response:", "reply:"):
        if t.lower().startswith(pre):
            t = t[len(pre):].strip()
    return t.strip("`").strip()

def compute_metrics(preds_raw, golds_raw):
    preds = [clean_text(p) for p in preds_raw]
    golds = [clean_text(g) for g in golds_raw]

    # em_list, f1_list, bleu_list, rouge_list, meteor_list = [], [], [], [], []
    f1_list, bleu_list, rouge_list, meteor_list = [], [], [], []
    for pred, gold in zip(preds, golds):
        # em_list.append(exact_match(pred, gold))
        f1_list.append(f1_score_overlap(pred, gold))
        bleu_list.append(bleu_score(pred, gold))
        rouge_list.append(rouge_l_score(pred, gold))
        meteor_list.append(meteor(pred, gold))

    # BERTScore on CUDA; drop empty pairs to avoid warnings
    mask = [bool(p.strip()) and bool(g.strip()) for p, g in zip(preds, golds)]
    preds_nz = [p for p, m in zip(preds, mask) if m]
    golds_nz = [g for g, m in zip(golds, mask) if m]
    if len(preds_nz) == 0:
        bert_f1_avg = 0.0
    else:
        P, R, F1 = bertscore(
            preds_nz, golds_nz,
            lang="en",
            model_type=BERTSCORE_MODEL,
            rescale_with_baseline=True,
            device=DEVICE
        )
        bert_f1_avg = float(F1.mean()) * 100.0

    n = max(1, len(f1_list))
    metrics = [
        # "Exact Match", 
        "F1-overlap", "BLEU", "ROUGE-L", "METEOR", "BERTScore-F1"]
    scores = [
        # round(sum(em_list) / n * 100, 2),
        round(sum(f1_list) / n * 100, 2),
        round(sum(bleu_list) / n * 100, 2),
        round(sum(rouge_list) / n * 100, 2),
        round(sum(meteor_list) / n * 100, 2),
        round(bert_f1_avg, 2),
    ]
    assert len(metrics) == len(scores), f"metrics={len(metrics)} scores={len(scores)}"

    rows = [{"Metric": m, "Score": s} for m, s in zip(metrics, scores)]
    return pl.DataFrame(rows)

# === Run all models and combine outputs ===
all_summaries = []

for key, MODEL_NAME in MODELS.items():
    OUTPUT_CSV = f"chatbot_result/{scenario}/scenario_{scenario_no}_{scenario}_results_{key}.csv"

    print(f"\n🚀 Running Evaluation for: {MODEL_NAME}")

    result_df = pl.read_csv(OUTPUT_CSV)
    preds = result_df["prediction"].to_list()
    golds = result_df["response"].to_list()

    summary = compute_metrics(preds, golds).with_columns(pl.lit(key).alias("Model"))
    all_summaries.append(summary)

# Combine all models (long)
if all_summaries:
    final_df = pl.concat(all_summaries).select(["Model", "Metric", "Score"])
    final_df.write_csv(os.path.join(OUT_DIR, f"Scenario_{scenario_no}_Evaluation_AllModels.csv"))

    # Pivot for side-by-side comparison
    pivot_df = final_df.pivot(index="Metric", columns="Model", values="Score")
    pivot_df.write_csv(os.path.join(OUT_DIR, f"Scenario_{scenario_no}_Evaluation_Pivot.csv"))

    print("\n📊 Combined (pivot) comparison:")
    print(pivot_df)
    print("\n✅ Saved under 'Evaluation/'")
    print(f"- Scenario_{scenario_no}_Evaluation_AllModels.csv")
    print(f"- Scenario_{scenario_no}_Evaluation_Pivot.csv")
else:
    print("⚠️ No model results were processed.")
# Out:
# 🚀 Running Evaluation for: meta-llama/Llama-3.2-1B
#
# 🚀 Running Evaluation for: Qwen/Qwen3-0.6B-Base
#
# 🚀 Running Evaluation for: allenai/OLMo-2-0425-1B
#
# 📊 Combined (pivot) comparison:
# shape: (5, 4)
# ┌──────────────┬───────┬───────┬───────┐
# │ Metric       ┆ llama ┆ qwen  ┆ olmo  │
# │ ---          ┆ ---   ┆ ---   ┆ ---   │
# │ str          ┆ f64   ┆ f64   ┆ f64   │
# ╞══════════════╪═══════╪═══════╪═══════╡
# │ F1-overlap   ┆ 32.53 ┆ 45.0  ┆ 32.34 │
# │ BLEU         ┆ 11.61 ┆ 20.61 ┆ 10.24 │
# │ ROUGE-L      ┆ 19.66 ┆ 27.38 ┆ 20.58 │
# │ METEOR       ┆ 21.67 ┆ 32.74 ┆ 19.66 │
# │ BERTScore-F1 ┆ 25.37 ┆ 36.18 ┆ 26.26 │
# └──────────────┴───────┴───────┴───────┘
#
# ✅ Saved under 'Evaluation/'
# - Scenario_E_Evaluation_AllModels.csv
# - Scenario_E_Evaluation_Pivot.csv
# /tmp/ipykernel_13172/4165006893.py:134: DeprecationWarning: the argument `columns` for `DataFrame.pivot` is deprecated. It was renamed to `on` in version 1.0.0.
#   pivot_df = final_df.pivot(index="Metric", columns="Model", values="Score")
