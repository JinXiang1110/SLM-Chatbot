# %%
import polars as pl
import os, math, string
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline
from peft import PeftModel
from transformers import BitsAndBytesConfig
import torch
import gc
from tqdm import tqdm
import numpy as np
import markdown

import lancedb
import nltk
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
from nltk.translate.meteor_score import meteor_score
from nltk.tokenize import word_tokenize, wordpunct_tokenize
from rouge_score import rouge_scorer
from bert_score import score as bertscore
from collections import Counter
import string
import random
import emoji

# === NLTK SETUP ===
nltk.download('punkt_tab')
nltk.download("wordnet")
smooth_fn = SmoothingFunction().method4
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/zorin17/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/zorin17/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
from huggingface_hub import login

# Insert your token here
login(token="")

# %%
gc.collect()
torch.cuda.empty_cache()
torch.cuda.ipc_collect()

# %%
df = pl.read_csv('hf://datasets/bitext/Bitext-customer-support-llm-chatbot-training-dataset/Bitext_Sample_Customer_Support_Training_Dataset_27K_responses-v11.csv')
# Data cleaning
# fill in null
df = df.with_columns([
    pl.col("instruction")
      .cast(str)
      .str.to_lowercase()
      .fill_null(""),
    
    pl.col("response")
      .cast(str)
      .str.to_lowercase()
      .fill_null(""),
    
    pl.col("intent")
      .cast(str)
      .fill_null("unknown")
])

# Remove emoji
def remove_emojis(text: str) -> str:
    return emoji.replace_emoji(text, replace="")  # Remove all emojis safely

# Apply to instruction and response
df = df.with_columns([
    pl.col("instruction").map_elements(remove_emojis).alias("instruction")
])

df = df.with_columns([
    pl.col("response").map_elements(remove_emojis).alias("response")
])

#Exclude noisy flags
# Filter out rows where 'flags' contains Z, Q, or W ===
flag = ["flags"]
df_z = df.filter(
    ~pl.col(flag).cast(str).str.contains("Z")
)

df_zw = df.filter(
    ~pl.col(flag).cast(str).str.contains("Z") &
    ~pl.col(flag).cast(str).str.contains("W")
)

df_clean = df.filter(
    ~pl.col(flag).cast(str).str.contains("Z") &
    ~pl.col(flag).cast(str).str.contains("W") &
    ~pl.col(flag).cast(str).str.contains("Q")
)

print(df_z.height)
print(df_zw.height)
print(df_clean.height)

category_counts = (
    df_clean
    .group_by("category")
    .agg(pl.count().alias("counts"))
    .sort("counts", descending=True)
)

print(category_counts)

# Filter only selected categories
selected_categories = ["ORDER", "REFUND", "SHIPPING", "DELIVERY"]
df_selected = df_clean.filter(
    pl.col("category").is_in(selected_categories)
)
# Out:
# /tmp/ipykernel_548/777344230.py:25: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns([
# /tmp/ipykernel_548/777344230.py:29: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns([
# 21586
# 20517
# 14454
# shape: (11, 2)
# ┌──────────────┬────────┐
# │ category     ┆ counts │
# │ ---          ┆ ---    │
# │ str          ┆ u32    │
# ╞══════════════╪════════╡
# │ ACCOUNT      ┆ 3251   │
# │ ORDER        ┆ 2152   │
# │ REFUND       ┆ 1527   │
# │ SHIPPING     ┆ 1156   │
# │ DELIVERY     ┆ 1102   │
# │ …            ┆ …      │
# │ INVOICE      ┆ 1076   │
# │ PAYMENT      ┆ 1028   │
# │ FEEDBACK     ┆ 1004   │
# │ CANCEL       ┆ 539    │
# │ SUBSCRIPTION ┆ 537    │
# └──────────────┴────────┘
# /tmp/ipykernel_548/777344230.py:58: DeprecationWarning: `pl.count()` is deprecated. Please use `pl.len()` instead.
# (Deprecated in version 0.20.5)
#   .agg(pl.count().alias("counts"))

# %%
# Split dataset by category
# === Configuration ===
LABEL_COL = "category"  # 🔁 Replace with "intent" or any stratification column
SPLIT_RATIO_TRAIN = 0.7
SPLIT_RATIO_VAL = 0.15
SEED = 123
df_final = df_selected.clone()

# === Stratified split logic ===
random.seed(SEED)
train_parts = []
test_parts = []
val_parts = []

for label in df_final[LABEL_COL].unique().to_list():
    group_df = df_final.filter(pl.col(LABEL_COL) == label)
    group_df = group_df.sample(n=len(group_df), shuffle=True, seed=SEED)

    n = len(group_df)
    train_idx = int(n * SPLIT_RATIO_TRAIN)
    val_idx = int(n * (SPLIT_RATIO_TRAIN + SPLIT_RATIO_VAL))

    train_parts.append(group_df[:train_idx])
    val_parts.append(group_df[train_idx:val_idx])
    test_parts.append(group_df[val_idx:])

# === Combine all groups
train_df = pl.concat(train_parts).sort(["category", "instruction"])
val_df = pl.concat(val_parts).sort(["category", "instruction"])
test_df = pl.concat(test_parts).sort(["category", "instruction"])

print("✅ Split sizes:")
print(f"Train: {len(train_df)}")
print(f"Val:   {len(val_df)}")
print(f"Test:  {len(test_df)}")

print("\n📊 Category distribution in test set:")
print(test_df.select([pl.col(LABEL_COL)]).to_series().value_counts())
# Out:
# ✅ Split sizes:
# Train: 4154
# Val:   890
# Test:  893
#
# 📊 Category distribution in test set:
# shape: (4, 2)
# ┌──────────┬───────┐
# │ category ┆ count │
# │ ---      ┆ ---   │
# │ str      ┆ u32   │
# ╞══════════╪═══════╡
# │ DELIVERY ┆ 166   │
# │ ORDER    ┆ 323   │
# │ REFUND   ┆ 230   │
# │ SHIPPING ┆ 174   │
# └──────────┴───────┘

# %%
# === Configuration ===
scenario_no = "F"
scenario    = "rag_prompt_ft"  

# Prompt-tuned generators: base + adapter
MODELS = {
    # "llama": {
    #     "base":    "meta-llama/Llama-3.2-1B",
    #     "adapter": "prompt-tune-outputs/Llama-3.2-1B-faq",
    # },
    # "qwen": {
    #     "base":    "Qwen/Qwen3-0.6B-Base",
    #     "adapter": "prompt-tune-outputs/Qwen3-0.6B-Base-faq",
    # },
    "olmo": {
        "base":    "allenai/OLMo-2-0425-1B",
        "adapter": "prompt-tune-outputs/OLMo-2-0425-1B-faq",
    },
}

OFFLOAD_DIR = "./offload"
USE_CUDA = torch.cuda.is_available()
SAVE_EVERY = 20

# === Load test set (pre-split externally)
questions = test_df["instruction"].cast(str).to_list()
answers = test_df["response"].cast(str).to_list()

# ----------------- RAG pieces -----------------

# Read data from LanceDB table
def load_faq_table():
    db = lancedb.connect("/home/zorin17/Desktop/LLM/")
    return db.open_table("LANCEDB_FAQ")

table = load_faq_table()

# Search reranker
def search(query, table, top_k=5, category=None, intent=None):
    s = table.search(query).limit(top_k)
    if category:
        s = s.where(f"category = '{category}'")
    if intent:
        s = s.where(f"intent = '{intent}'")

    result = s.to_list()
    if not result:
        return "[Context 1]:\n(no relevant context found)\n"

    blocks = []
    for i, r in enumerate(result, 1):
        text = (r.get("text") or "").strip()
        # optional: guard against empty rows
        if not text:
            text = "(empty context)"
        blocks.append(f"[Context {i}]:\n{text}\n")
    return "\n".join(blocks)

# Prompt template (system + user with explicit sections)
base_prompt = """You are a helpful retail assistant. Your task is to answer the user question using provided contexts as the answer. 
You must make your response organized and structured.

User question: {}
Contexts:
{}
"""
custom_template = """{% if messages | selectattr('role','equalto','system') | list %}
System: {{ (messages | selectattr('role','equalto','system') | map(attribute='content') | list) | join('\\n') }}
{% endif %}
{% for m in messages %}
{% if m['role'] == 'user' -%}
User: {{ m['content'] }}
{% elif m['role'] == 'assistant' -%}
Assistant: {{ m['content'] }}
{% elif m['role'] == 'tool' -%}
Tool: {{ m['content'] }}
{% elif m['role'] == 'developer' -%}
System: {{ m['content'] }}
{% else -%}
{{ m['role']|capitalize }}: {{ m['content'] }}
{% endif -%}
{% endfor %}
Assistant:"""

# ----------------- RAG pieces End -----------------

# ----------------- Utilities -----------------
# === Safe append function
def append_to_csv(new_data: pl.DataFrame, path: str):
    if os.path.exists(path):
        existing = pl.read_csv(path)
        combined = existing.vstack(new_data)
    else:
        combined = new_data
    combined.write_csv(path)

def adaptive_max_new_tokens(gold_text: str, tokenizer, min_nt=48, max_nt=300, mult=1.3, bonus=16) -> int:
    n_gold = len(tokenizer(gold_text, add_special_tokens=False).input_ids)
    est = int(round(mult * n_gold) + bonus)
    return int(np.clip(est, min_nt, max_nt))

def _count_tokens(s, tok): 
    return len(tok(s, add_special_tokens=False).input_ids)

def safe_pack_contexts(question, contexts, tokenizer, max_src_tokens=700):
    head = "You are a helpful retail assistant. Your task is to answer the user question using provided contexts as the answer.\n\n"
    used = _count_tokens(head + f"User question: {question}\nContexts:\n", tokenizer)
    kept, buf = [], contexts.splitlines()
    for c in buf:
        block = c.strip() + "\n"
        t = _count_tokens(block, tokenizer)
        if used + t > max_src_tokens:
            break
        kept.append(block); used += t
    return "".join(kept)

def generate_one(tokenizer, hf_model, base_prompt, question, context,
                 temperature=0.0, max_new_tokens=128, return_html=False):
    system_content = base_prompt.format(question, context)
    messages = [
        {"role": "system", "content": system_content},
        {"role": "user",   "content": f"Question: {question}\n\nContext:\n{context}"}
    ]
    prompt = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True,
        chat_template=custom_template
    )
    inputs = tokenizer(prompt, return_tensors="pt").to(hf_model.device)
    input_len = inputs["input_ids"].shape[-1]

    with torch.inference_mode():
        outputs = hf_model.generate(
            **inputs,
            do_sample=(temperature > 0),
            temperature=temperature,
            top_p=0.95,
            max_new_tokens=max_new_tokens,
            no_repeat_ngram_size=3,
            eos_token_id=tokenizer.eos_token_id,
            pad_token_id=tokenizer.pad_token_id,
            return_dict_in_generate=True,
        )

    new_tokens = outputs.sequences[0, input_len:]
    text = tokenizer.decode(new_tokens, skip_special_tokens=True).strip()
    return markdown.markdown(text) if return_html else text

def rag_answer(tokenizer, hf_model, question, temperature=0.0, category=None, intent=None, max_new_tokens=128):
    raw_ctx = search(question, table, top_k=5, category=category, intent=intent)
    context = safe_pack_contexts(question, raw_ctx, tokenizer, max_src_tokens=700)
    return generate_one(tokenizer, hf_model, base_prompt, question, context,
                        temperature=temperature, max_new_tokens=max_new_tokens, return_html=False)

# === Prompt-tuning loader ===
def load_tokenizer(model_or_path: str):
    tok = AutoTokenizer.from_pretrained(model_or_path, use_fast=True, trust_remote_code=True)
    if tok.pad_token is None:
        tok.pad_token = tok.eos_token
    tok.padding_side = "right"
    return tok

def load_base_4bit(base_name: str, offload_dir: str):
    supports_bf16 = torch.cuda.is_available() and torch.cuda.get_device_capability(0)[0] >= 8
    bnb = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_use_double_quant=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=torch.bfloat16 if supports_bf16 else torch.float16,
    )
    return AutoModelForCausalLM.from_pretrained(
        base_name,
        quantization_config=bnb,
        device_map="auto",
        attn_implementation="sdpa",
        torch_dtype=torch.bfloat16 if supports_bf16 else torch.float16,
        offload_folder=offload_dir,
        trust_remote_code=True,
    )

def enable_inference_cache(model):
    if getattr(model.config, "use_cache", None) is not True:
        model.config.use_cache = True

# ----------------- Run all Prompt-tuned generators -----------------
for key, cfg in MODELS.items():
    BASE = cfg["base"]
    ADAPTER_DIR = cfg["adapter"]

    # sanity: adapter exists
    assert os.path.exists(ADAPTER_DIR), f"Adapter not found for {key}: {ADAPTER_DIR}"

    OUTPUT_CSV = f"chatbot_result/{scenario}/scenario_{scenario_no}_{scenario}_results_{key}.csv"
    print(f"\n🚀 Scenario {scenario_no} (RAG + Prompt-Tuned) — Inference for: {BASE} + {ADAPTER_DIR}")
    os.makedirs(os.path.dirname(OUTPUT_CSV), exist_ok=True)

    torch.cuda.empty_cache(); torch.cuda.ipc_collect()

    # --- Load base (4-bit) + attach LoRA adapter ---
    tokenizer = load_tokenizer(BASE)
    base_model = load_base_4bit(BASE, OFFLOAD_DIR)
    hf_model  = PeftModel.from_pretrained(base_model, ADAPTER_DIR)
    enable_inference_cache(hf_model)
    hf_model.eval()

    # resume
    if os.path.exists(OUTPUT_CSV):
        existing = pl.read_csv(OUTPUT_CSV)
        done = set(existing["instruction"].to_list())
        print(f"🔄 Resuming from {len(done)} rows...")
    else:
        done = set()

    results = []
    for question, gold in tqdm(zip(questions, answers), total=len(questions), desc=f"{key.upper()} RAG+FT"):
        if question in done:
            continue

        max_nt = adaptive_max_new_tokens(gold, tokenizer, min_nt=48, max_nt=300, mult=1.3, bonus=16)

        try:
            pred = rag_answer(
                tokenizer, hf_model, question,
                temperature=0.0,
                category=None, intent=None,
                max_new_tokens=max_nt
            )
            if "Assistant:" in pred:
                pred = pred.split("Assistant:")[-1].strip()

        except Exception as e:
            print(f"⚠️ Error on: {question[:60]}... Skip. Reason: {e}")
            continue

        results.append((question, gold, pred))

        if len(results) >= SAVE_EVERY:
            chunk_df = pl.DataFrame(results, schema=["instruction", "response", "prediction"])
            enriched = test_df.join(chunk_df, on=["instruction", "response"], how="inner")
            append_to_csv(enriched, OUTPUT_CSV)
            results = []

    if results:
        chunk_df = pl.DataFrame(results, schema=["instruction", "response", "prediction"])
        enriched = test_df.join(chunk_df, on=["instruction", "response"], how="inner")
        append_to_csv(enriched, OUTPUT_CSV)

    print(f"✅ Done with {key}. Results saved to {OUTPUT_CSV}")

    # cleanup VRAM
    del tokenizer, hf_model, base_model
    gc.collect()
    torch.cuda.empty_cache()
    torch.cuda.ipc_collect()
# Out:
# 🚀 Scenario F (RAG + Prompt-Tuned) — Inference for: allenai/OLMo-2-0425-1B + prompt-tune-outputs/OLMo-2-0425-1B-faq
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# OLMO RAG+FT:   0%|          | 0/893 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# /home/zorin17/miniconda3/envs/llm/lib/python3.10/site-packages/peft/peft_model.py:2066: UserWarning: Position ids are not supported for parameter efficient tuning. Ignoring position ids.
#   warnings.warn("Position ids are not supported for parameter efficient tuning. Ignoring position ids.")
# OLMO RAG+FT:   0%|          | 1/893 [00:13<3:15:11, 13.13s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   0%|          | 2/893 [00:34<4:26:07, 17.92s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   0%|          | 3/893 [00:41<3:11:26, 12.91s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   0%|          | 4/893 [00:47<2:33:23, 10.35s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   1%|          | 5/893 [00:49<1:45:33,  7.13s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   1%|          | 6/893 [00:50<1:15:53,  5.13s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   1%|          | 7/893 [00:52<59:21,  4.02s/it]  The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   1%|          | 8/893 [00:59<1:16:29,  5.19s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   1%|          | 9/893 [01:08<1:31:38,  6.22s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   1%|          | 10/893 [01:15<1:34:26,  6.42s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   1%|          | 11/893 [01:22<1:38:46,  6.72s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   1%|▏         | 12/893 [01:23<1:14:03,  5.04s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   1%|▏         | 13/893 [01:31<1:26:11,  5.88s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   2%|▏         | 14/893 [01:57<2:54:06, 11.88s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   2%|▏         | 15/893 [02:07<2:47:50, 11.47s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   2%|▏         | 16/893 [02:17<2:41:22, 11.04s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   2%|▏         | 17/893 [02:25<2:27:21, 10.09s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   2%|▏         | 18/893 [02:42<2:55:58, 12.07s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   2%|▏         | 19/893 [02:44<2:10:33,  8.96s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# /home/zorin17/miniconda3/envs/llm/lib/python3.10/functools.py:889: DataOrientationWarning: Row orientation inferred during DataFrame construction. Explicitly specify the orientation by passing `orient="row"` to silence this warning.
#   return dispatch(args[0].__class__)(*args, **kw)
# OLMO RAG+FT:   2%|▏         | 20/893 [03:09<3:22:29, 13.92s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   2%|▏         | 21/893 [03:17<2:57:29, 12.21s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   2%|▏         | 22/893 [03:38<3:33:57, 14.74s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   3%|▎         | 23/893 [04:04<4:24:35, 18.25s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   3%|▎         | 24/893 [04:29<4:49:34, 19.99s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   3%|▎         | 25/893 [04:55<5:17:38, 21.96s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   3%|▎         | 26/893 [05:20<5:31:37, 22.95s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   3%|▎         | 27/893 [05:22<3:57:41, 16.47s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   3%|▎         | 28/893 [05:37<3:53:19, 16.18s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   3%|▎         | 29/893 [05:49<3:34:18, 14.88s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   3%|▎         | 30/893 [06:01<3:19:48, 13.89s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   3%|▎         | 31/893 [06:18<3:35:08, 14.98s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   4%|▎         | 32/893 [06:26<3:04:36, 12.86s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   4%|▎         | 33/893 [06:37<2:55:18, 12.23s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   4%|▍         | 34/893 [06:46<2:41:06, 11.25s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   4%|▍         | 35/893 [07:07<3:22:05, 14.13s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   4%|▍         | 36/893 [07:17<3:07:21, 13.12s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   4%|▍         | 37/893 [07:20<2:20:59,  9.88s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   4%|▍         | 38/893 [07:21<1:45:06,  7.38s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   4%|▍         | 39/893 [07:46<2:59:57, 12.64s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   4%|▍         | 40/893 [07:49<2:16:05,  9.57s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   5%|▍         | 41/893 [07:56<2:07:37,  8.99s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   5%|▍         | 42/893 [08:18<3:00:56, 12.76s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   5%|▍         | 43/893 [08:44<3:57:32, 16.77s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   5%|▍         | 44/893 [09:10<4:37:16, 19.60s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   5%|▌         | 45/893 [09:27<4:23:51, 18.67s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   5%|▌         | 46/893 [09:51<4:48:10, 20.41s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   5%|▌         | 47/893 [09:52<3:26:47, 14.67s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   5%|▌         | 48/893 [10:03<3:07:33, 13.32s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   5%|▌         | 49/893 [10:06<2:25:08, 10.32s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   6%|▌         | 50/893 [10:24<2:56:45, 12.58s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   6%|▌         | 51/893 [10:37<2:57:46, 12.67s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   6%|▌         | 52/893 [10:38<2:12:06,  9.43s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   6%|▌         | 53/893 [11:00<3:01:41, 12.98s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   6%|▌         | 54/893 [11:15<3:13:12, 13.82s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   6%|▌         | 55/893 [11:17<2:20:01, 10.03s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   6%|▋         | 56/893 [11:26<2:15:38,  9.72s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   6%|▋         | 57/893 [11:51<3:21:14, 14.44s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   6%|▋         | 58/893 [12:17<4:08:43, 17.87s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   7%|▋         | 59/893 [12:25<3:26:30, 14.86s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   7%|▋         | 60/893 [12:34<3:01:24, 13.07s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   7%|▋         | 61/893 [12:42<2:40:06, 11.55s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   7%|▋         | 62/893 [12:57<2:54:42, 12.61s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   7%|▋         | 63/893 [13:19<3:34:41, 15.52s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   7%|▋         | 64/893 [13:29<3:10:17, 13.77s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   7%|▋         | 65/893 [13:48<3:32:56, 15.43s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   7%|▋         | 66/893 [14:04<3:33:30, 15.49s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   8%|▊         | 67/893 [14:14<3:12:05, 13.95s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   8%|▊         | 68/893 [14:22<2:48:01, 12.22s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   8%|▊         | 69/893 [14:44<3:27:36, 15.12s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   8%|▊         | 70/893 [15:00<3:28:16, 15.18s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   8%|▊         | 71/893 [15:24<4:05:23, 17.91s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   8%|▊         | 72/893 [15:34<3:33:23, 15.59s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   8%|▊         | 73/893 [15:49<3:29:16, 15.31s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   8%|▊         | 74/893 [16:06<3:36:06, 15.83s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   8%|▊         | 75/893 [16:15<3:11:04, 14.02s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   9%|▊         | 76/893 [16:36<3:36:41, 15.91s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   9%|▊         | 77/893 [17:00<4:12:07, 18.54s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   9%|▊         | 78/893 [17:24<4:33:55, 20.17s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   9%|▉         | 79/893 [17:50<4:55:37, 21.79s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   9%|▉         | 80/893 [18:10<4:49:15, 21.35s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   9%|▉         | 81/893 [18:21<4:04:15, 18.05s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   9%|▉         | 82/893 [18:27<3:15:08, 14.44s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   9%|▉         | 83/893 [18:52<3:57:48, 17.62s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:   9%|▉         | 84/893 [19:01<3:25:19, 15.23s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  10%|▉         | 85/893 [19:09<2:54:16, 12.94s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  10%|▉         | 86/893 [19:10<2:06:37,  9.42s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  10%|▉         | 87/893 [19:11<1:33:17,  6.94s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  10%|▉         | 88/893 [19:37<2:49:32, 12.64s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  10%|▉         | 89/893 [19:59<3:25:29, 15.34s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  10%|█         | 90/893 [20:19<3:45:55, 16.88s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  10%|█         | 91/893 [20:42<4:08:37, 18.60s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  10%|█         | 92/893 [21:05<4:24:08, 19.79s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  10%|█         | 93/893 [21:14<3:40:51, 16.56s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  11%|█         | 94/893 [21:22<3:08:11, 14.13s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  11%|█         | 95/893 [21:30<2:45:13, 12.42s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  11%|█         | 96/893 [21:56<3:35:35, 16.23s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  11%|█         | 97/893 [22:04<3:02:48, 13.78s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  11%|█         | 98/893 [22:25<3:34:10, 16.16s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  11%|█         | 99/893 [22:27<2:34:52, 11.70s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  11%|█         | 100/893 [22:29<1:55:53,  8.77s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  11%|█▏        | 101/893 [22:49<2:42:28, 12.31s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  11%|█▏        | 102/893 [22:59<2:33:51, 11.67s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  12%|█▏        | 103/893 [23:22<3:16:52, 14.95s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  12%|█▏        | 104/893 [23:34<3:06:36, 14.19s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  12%|█▏        | 105/893 [23:43<2:45:31, 12.60s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  12%|█▏        | 106/893 [23:58<2:52:25, 13.15s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  12%|█▏        | 107/893 [24:06<2:31:56, 11.60s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  12%|█▏        | 108/893 [24:13<2:13:46, 10.22s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  12%|█▏        | 109/893 [24:14<1:38:17,  7.52s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  12%|█▏        | 110/893 [24:22<1:41:48,  7.80s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  12%|█▏        | 111/893 [24:46<2:44:10, 12.60s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  13%|█▎        | 112/893 [24:48<2:01:39,  9.35s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  13%|█▎        | 113/893 [24:51<1:38:49,  7.60s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  13%|█▎        | 114/893 [25:17<2:50:14, 13.11s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  13%|█▎        | 115/893 [25:39<3:24:50, 15.80s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  13%|█▎        | 116/893 [26:06<4:05:32, 18.96s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  13%|█▎        | 117/893 [26:07<2:56:23, 13.64s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  13%|█▎        | 118/893 [26:15<2:35:43, 12.06s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  13%|█▎        | 119/893 [26:25<2:26:26, 11.35s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  13%|█▎        | 120/893 [26:48<3:09:36, 14.72s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  14%|█▎        | 121/893 [27:06<3:23:09, 15.79s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  14%|█▎        | 122/893 [27:16<3:00:50, 14.07s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  14%|█▍        | 123/893 [27:20<2:20:02, 10.91s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  14%|█▍        | 124/893 [27:27<2:05:51,  9.82s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  14%|█▍        | 125/893 [27:36<2:02:09,  9.54s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  14%|█▍        | 126/893 [27:37<1:30:04,  7.05s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  14%|█▍        | 127/893 [28:02<2:37:06, 12.31s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  14%|█▍        | 128/893 [28:22<3:07:25, 14.70s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  14%|█▍        | 129/893 [28:30<2:43:55, 12.87s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  15%|█▍        | 130/893 [28:40<2:31:37, 11.92s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  15%|█▍        | 131/893 [28:51<2:26:36, 11.54s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  15%|█▍        | 132/893 [29:01<2:22:08, 11.21s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  15%|█▍        | 133/893 [29:17<2:38:29, 12.51s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  15%|█▌        | 134/893 [29:19<1:58:03,  9.33s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  15%|█▌        | 135/893 [29:21<1:29:42,  7.10s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  15%|█▌        | 136/893 [29:23<1:09:56,  5.54s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  15%|█▌        | 137/893 [29:37<1:42:25,  8.13s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  15%|█▌        | 138/893 [29:40<1:25:01,  6.76s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  16%|█▌        | 139/893 [29:44<1:12:50,  5.80s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  16%|█▌        | 140/893 [29:59<1:48:40,  8.66s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  16%|█▌        | 141/893 [30:05<1:38:33,  7.86s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  16%|█▌        | 142/893 [30:16<1:49:55,  8.78s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  16%|█▌        | 143/893 [30:19<1:27:50,  7.03s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  16%|█▌        | 144/893 [30:45<2:40:14, 12.84s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  16%|█▌        | 145/893 [31:06<3:10:56, 15.32s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  16%|█▋        | 146/893 [31:33<3:52:44, 18.69s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  16%|█▋        | 147/893 [31:58<4:15:56, 20.59s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  17%|█▋        | 148/893 [32:15<4:02:12, 19.51s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  17%|█▋        | 149/893 [32:37<4:10:57, 20.24s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  17%|█▋        | 150/893 [32:47<3:33:47, 17.26s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  17%|█▋        | 151/893 [33:10<3:53:35, 18.89s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  17%|█▋        | 152/893 [33:12<2:50:21, 13.79s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  17%|█▋        | 153/893 [33:22<2:35:31, 12.61s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  17%|█▋        | 154/893 [33:49<3:29:46, 17.03s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  17%|█▋        | 155/893 [34:08<3:35:19, 17.51s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  17%|█▋        | 156/893 [34:12<2:47:57, 13.67s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  18%|█▊        | 157/893 [34:35<3:20:24, 16.34s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  18%|█▊        | 158/893 [34:47<3:05:28, 15.14s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  18%|█▊        | 159/893 [34:56<2:40:38, 13.13s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  18%|█▊        | 160/893 [35:10<2:44:38, 13.48s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  18%|█▊        | 161/893 [35:27<2:56:55, 14.50s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  18%|█▊        | 162/893 [35:35<2:33:57, 12.64s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  18%|█▊        | 163/893 [35:46<2:25:38, 11.97s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  18%|█▊        | 164/893 [35:57<2:21:47, 11.67s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  18%|█▊        | 165/893 [36:20<3:05:00, 15.25s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  19%|█▊        | 166/893 [36:28<2:38:54, 13.12s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  19%|█▊        | 167/893 [36:35<2:15:28, 11.20s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  19%|█▉        | 168/893 [37:01<3:07:20, 15.50s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  19%|█▉        | 169/893 [37:10<2:43:52, 13.58s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  19%|█▉        | 170/893 [37:19<2:26:29, 12.16s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  19%|█▉        | 171/893 [37:29<2:19:28, 11.59s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  19%|█▉        | 172/893 [37:37<2:05:19, 10.43s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  19%|█▉        | 173/893 [37:52<2:24:35, 12.05s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  19%|█▉        | 174/893 [38:06<2:29:10, 12.45s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  20%|█▉        | 175/893 [38:19<2:30:01, 12.54s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  20%|█▉        | 176/893 [38:20<1:49:04,  9.13s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  20%|█▉        | 177/893 [38:25<1:36:57,  8.13s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  20%|█▉        | 178/893 [38:34<1:37:54,  8.22s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  20%|██        | 179/893 [38:37<1:19:34,  6.69s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  20%|██        | 180/893 [38:50<1:41:01,  8.50s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  20%|██        | 181/893 [39:01<1:50:10,  9.28s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  20%|██        | 182/893 [39:25<2:43:29, 13.80s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  20%|██        | 183/893 [39:51<3:27:18, 17.52s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  21%|██        | 184/893 [40:00<2:56:46, 14.96s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  21%|██        | 185/893 [40:09<2:35:09, 13.15s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  21%|██        | 186/893 [40:18<2:18:57, 11.79s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  21%|██        | 187/893 [40:29<2:14:30, 11.43s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  21%|██        | 188/893 [40:36<2:01:28, 10.34s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  21%|██        | 189/893 [40:47<2:03:28, 10.52s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  21%|██▏       | 190/893 [41:13<2:57:05, 15.11s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  21%|██▏       | 191/893 [41:37<3:26:38, 17.66s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  22%|██▏       | 192/893 [41:49<3:08:23, 16.12s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  22%|██▏       | 193/893 [41:55<2:32:32, 13.08s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  22%|██▏       | 194/893 [42:00<2:04:45, 10.71s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  22%|██▏       | 195/893 [42:08<1:53:36,  9.77s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  22%|██▏       | 196/893 [42:10<1:28:16,  7.60s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  22%|██▏       | 197/893 [42:23<1:43:37,  8.93s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  22%|██▏       | 198/893 [42:29<1:36:09,  8.30s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  22%|██▏       | 199/893 [42:56<2:39:22, 13.78s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  22%|██▏       | 200/893 [43:00<2:06:59, 11.00s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  23%|██▎       | 201/893 [43:04<1:40:01,  8.67s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  23%|██▎       | 202/893 [43:12<1:38:10,  8.52s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  23%|██▎       | 203/893 [43:38<2:39:35, 13.88s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  23%|██▎       | 204/893 [44:03<3:18:37, 17.30s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  23%|██▎       | 205/893 [44:24<3:29:55, 18.31s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  23%|██▎       | 206/893 [44:31<2:51:05, 14.94s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  23%|██▎       | 207/893 [44:59<3:34:41, 18.78s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  23%|██▎       | 208/893 [45:23<3:52:11, 20.34s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  23%|██▎       | 209/893 [45:49<4:10:48, 22.00s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  24%|██▎       | 210/893 [46:15<4:24:00, 23.19s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  24%|██▎       | 211/893 [46:41<4:32:48, 24.00s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  24%|██▎       | 212/893 [46:45<3:23:54, 17.97s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  24%|██▍       | 213/893 [46:46<2:28:58, 13.15s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  24%|██▍       | 214/893 [46:50<1:56:04, 10.26s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  24%|██▍       | 215/893 [47:02<2:00:31, 10.67s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  24%|██▍       | 216/893 [47:08<1:45:09,  9.32s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  24%|██▍       | 217/893 [47:13<1:30:56,  8.07s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  24%|██▍       | 218/893 [47:17<1:15:54,  6.75s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  25%|██▍       | 219/893 [47:18<57:02,  5.08s/it]  The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  25%|██▍       | 220/893 [47:29<1:18:41,  7.02s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  25%|██▍       | 221/893 [47:41<1:34:19,  8.42s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  25%|██▍       | 222/893 [47:52<1:42:14,  9.14s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  25%|██▍       | 223/893 [48:03<1:48:46,  9.74s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  25%|██▌       | 224/893 [48:13<1:50:51,  9.94s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  25%|██▌       | 225/893 [48:23<1:49:30,  9.84s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  25%|██▌       | 226/893 [48:48<2:39:24, 14.34s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  25%|██▌       | 227/893 [49:13<3:15:51, 17.64s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# ...
# OLMO RAG+FT:  91%|█████████▏| 817/893 [2:54:19<16:57, 13.39s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  92%|█████████▏| 818/893 [2:54:43<20:40, 16.54s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  92%|█████████▏| 819/893 [2:55:06<22:43, 18.43s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  92%|█████████▏| 820/893 [2:55:29<24:10, 19.88s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  92%|█████████▏| 821/893 [2:55:48<23:16, 19.39s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  92%|█████████▏| 822/893 [2:55:48<16:17, 13.76s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  92%|█████████▏| 823/893 [2:55:50<11:48, 10.12s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  92%|█████████▏| 824/893 [2:55:51<08:27,  7.35s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  92%|█████████▏| 825/893 [2:56:11<12:33, 11.08s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  92%|█████████▏| 826/893 [2:56:29<14:56, 13.39s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  93%|█████████▎| 827/893 [2:56:32<11:19, 10.30s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  93%|█████████▎| 828/893 [2:56:36<09:08,  8.44s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  93%|█████████▎| 829/893 [2:56:41<07:43,  7.25s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  93%|█████████▎| 830/893 [2:56:42<05:31,  5.27s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  93%|█████████▎| 831/893 [2:56:45<05:00,  4.85s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  93%|█████████▎| 832/893 [2:56:46<03:44,  3.69s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  93%|█████████▎| 833/893 [2:56:53<04:24,  4.41s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  93%|█████████▎| 834/893 [2:57:01<05:34,  5.67s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  94%|█████████▎| 835/893 [2:57:09<06:00,  6.22s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  94%|█████████▎| 836/893 [2:57:15<06:02,  6.37s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  94%|█████████▎| 837/893 [2:57:17<04:42,  5.05s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  94%|█████████▍| 838/893 [2:57:29<06:25,  7.00s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  94%|█████████▍| 839/893 [2:57:32<05:15,  5.84s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  94%|█████████▍| 840/893 [2:57:33<03:55,  4.44s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  94%|█████████▍| 841/893 [2:57:43<05:17,  6.10s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  94%|█████████▍| 842/893 [2:57:44<03:54,  4.60s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  94%|█████████▍| 843/893 [2:57:47<03:19,  3.99s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  95%|█████████▍| 844/893 [2:58:07<07:15,  8.89s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  95%|█████████▍| 845/893 [2:58:09<05:20,  6.68s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  95%|█████████▍| 846/893 [2:58:13<04:41,  5.98s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  95%|█████████▍| 847/893 [2:58:37<08:49, 11.50s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  95%|█████████▍| 848/893 [2:58:39<06:27,  8.62s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  95%|█████████▌| 849/893 [2:58:41<04:53,  6.67s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  95%|█████████▌| 850/893 [2:58:48<04:51,  6.77s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  95%|█████████▌| 851/893 [2:59:13<08:30, 12.16s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  95%|█████████▌| 852/893 [2:59:40<11:14, 16.44s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  96%|█████████▌| 853/893 [2:59:42<08:06, 12.15s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  96%|█████████▌| 854/893 [2:59:44<05:56,  9.15s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  96%|█████████▌| 855/893 [2:59:49<04:56,  7.81s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  96%|█████████▌| 856/893 [3:00:14<08:00, 12.99s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  96%|█████████▌| 857/893 [3:00:19<06:29, 10.83s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  96%|█████████▌| 858/893 [3:00:24<05:09,  8.85s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  96%|█████████▌| 859/893 [3:00:26<03:54,  6.91s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  96%|█████████▋| 860/893 [3:00:34<03:57,  7.19s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  96%|█████████▋| 861/893 [3:00:37<03:11,  6.00s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  97%|█████████▋| 862/893 [3:00:43<03:04,  5.94s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  97%|█████████▋| 863/893 [3:00:46<02:33,  5.13s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  97%|█████████▋| 864/893 [3:00:48<02:00,  4.17s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  97%|█████████▋| 865/893 [3:01:09<04:14,  9.08s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  97%|█████████▋| 866/893 [3:01:19<04:18,  9.56s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  97%|█████████▋| 867/893 [3:01:25<03:39,  8.44s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  97%|█████████▋| 868/893 [3:01:50<05:35, 13.41s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  97%|█████████▋| 869/893 [3:01:53<04:07, 10.32s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  97%|█████████▋| 870/893 [3:01:54<02:51,  7.46s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  98%|█████████▊| 871/893 [3:01:57<02:17,  6.26s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  98%|█████████▊| 872/893 [3:02:02<02:02,  5.81s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  98%|█████████▊| 873/893 [3:02:18<02:54,  8.74s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  98%|█████████▊| 874/893 [3:02:30<03:04,  9.73s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  98%|█████████▊| 875/893 [3:02:33<02:21,  7.88s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  98%|█████████▊| 876/893 [3:02:34<01:39,  5.83s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  98%|█████████▊| 877/893 [3:02:46<02:02,  7.63s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  98%|█████████▊| 878/893 [3:02:49<01:30,  6.02s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  98%|█████████▊| 879/893 [3:03:12<02:35, 11.12s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  99%|█████████▊| 880/893 [3:03:14<01:49,  8.39s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  99%|█████████▊| 881/893 [3:03:33<02:21, 11.78s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  99%|█████████▉| 882/893 [3:03:46<02:13, 12.17s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  99%|█████████▉| 883/893 [3:04:08<02:28, 14.89s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  99%|█████████▉| 884/893 [3:04:28<02:27, 16.39s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  99%|█████████▉| 885/893 [3:04:41<02:03, 15.50s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  99%|█████████▉| 886/893 [3:04:49<01:32, 13.24s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  99%|█████████▉| 887/893 [3:04:51<00:58,  9.80s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT:  99%|█████████▉| 888/893 [3:04:55<00:40,  8.06s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT: 100%|█████████▉| 889/893 [3:05:00<00:28,  7.21s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT: 100%|█████████▉| 890/893 [3:05:06<00:20,  6.80s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT: 100%|█████████▉| 891/893 [3:05:30<00:24, 12.03s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT: 100%|█████████▉| 892/893 [3:05:36<00:10, 10.36s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# OLMO RAG+FT: 100%|██████████| 893/893 [3:05:49<00:00, 12.49s/it]
# ✅ Done with olmo. Results saved to chatbot_result/rag_prompt_ft/scenario_F_rag_prompt_ft_results_olmo.csv

# %%
# === Config ===
scenario_no = "F"
scenario    = "rag_prompt_ft"
DEVICE = "cuda"
MODELS = {
    "llama":    "meta-llama/Llama-3.2-1B",
    "qwen":     "Qwen/Qwen3-0.6B-Base",
    "olmo":     "allenai/OLMo-2-0425-1B",
}

BERTSCORE_MODEL = "microsoft/deberta-base-mnli"  # fast & solid for FAQ/QA

# NEW: memory safety knobs (no impact on scores)
import os, torch
os.environ.setdefault("PYTORCH_CUDA_ALLOC_CONF", "expandable_segments:True")
BERTSCORE_BATCH_SIZE = 4     # smaller batch to reduce VRAM peak (no score change)
BERTSCORE_CHUNK_SIZE = 600   # process pairs in chunks (no score change)

# Output folder
OUT_DIR = "Evaluation"
os.makedirs(OUT_DIR, exist_ok=True)

# BLEU smoothing (method4 is friendlier for short answers)
smooth_fn = SmoothingFunction().method4
# Cache rouge scorer once
rouge = rouge_scorer.RougeScorer(["rougeL"], use_stemmer=True)

# === Helpers ===
def _safe_text(x):
    return "" if x is None or (isinstance(x, float) and math.isnan(x)) else str(x)

def normalize(text: str) -> list[str]:
    text = _safe_text(text).lower().translate(str.maketrans('', '', string.punctuation))
    return wordpunct_tokenize(text)

def f1_score_overlap(pred: str, gold: str) -> float:
    pred_tokens = normalize(pred)
    gold_tokens = normalize(gold)
    if not pred_tokens or not gold_tokens:
        return 0.0
    common = Counter(pred_tokens) & Counter(gold_tokens)
    num_same = sum(common.values())
    if num_same == 0:
        return 0.0
    precision = num_same / len(pred_tokens)
    recall = num_same / len(gold_tokens)
    return 2 * precision * recall / (precision + recall)

def bleu_score(pred: str, gold: str) -> float:
    # BLEU-2 is fairer for short FAQ answers
    return sentence_bleu(
        [normalize(gold)], normalize(pred),
        weights=(0.5, 0.5, 0, 0),
        smoothing_function=smooth_fn
    )

def rouge_l_score(pred: str, gold: str) -> float:
    return rouge.score(_safe_text(gold), _safe_text(pred))["rougeL"].fmeasure

def meteor(pred: str, gold: str) -> float:
    return meteor_score([normalize(gold)], normalize(pred))

def clean_text(t: str) -> str:
    t = _safe_text(t).strip()
    for pre in ("answer:", "response:", "reply:"):
        if t.lower().startswith(pre):
            t = t[len(pre):].strip()
    return t.strip("`").strip()

# --- BERTScore with GPU-first, CPU fallback on OOM (identical results) ---
def _bertscore_mean_F1(preds_nz: list[str], golds_nz: list[str]) -> float:
    if len(preds_nz) == 0:
        return 0.0

    def _run(device: str) -> float:
        if device.startswith("cuda"):
            torch.cuda.empty_cache()
        all_f1 = []
        for i in range(0, len(preds_nz), BERTSCORE_CHUNK_SIZE):
            p_chunk = preds_nz[i:i+BERTSCORE_CHUNK_SIZE]
            g_chunk = golds_nz[i:i+BERTSCORE_CHUNK_SIZE]
            P, R, F1 = bertscore(
                p_chunk, g_chunk,
                lang="en",
                model_type=BERTSCORE_MODEL,
                rescale_with_baseline=True,
                device=device,                      # cuda OR cpu
                batch_size=BERTSCORE_BATCH_SIZE,
            )
            all_f1.append(F1)
            if device.startswith("cuda"):
                torch.cuda.empty_cache()
        return float(torch.cat(all_f1).mean()) * 100.0

    # Try CUDA first; if OOM, re-run entirely on CPU
    try:
        return _run(DEVICE)
    except RuntimeError as e:
        if "out of memory" in str(e).lower():
            if torch.cuda.is_available():
                torch.cuda.empty_cache()
            return _run("cpu")  # same model/settings; numerically equivalent up to tiny fp noise
        raise

def compute_metrics(preds_raw, golds_raw):
    preds = [clean_text(p) for p in preds_raw]
    golds = [clean_text(g) for g in golds_raw]

    f1_list, bleu_list, rouge_list, meteor_list = [], [], [], []
    for pred, gold in zip(preds, golds):
        f1_list.append(f1_score_overlap(pred, gold))
        bleu_list.append(bleu_score(pred, gold))
        rouge_list.append(rouge_l_score(pred, gold))
        meteor_list.append(meteor(pred, gold))

    # BERTScore; drop empty pairs
    mask = [bool(p.strip()) and bool(g.strip()) for p, g in zip(preds, golds)]
    preds_nz = [p for p, m in zip(preds, mask) if m]
    golds_nz = [g for g, m in zip(golds, mask) if m]
    bert_f1_avg = _bertscore_mean_F1(preds_nz, golds_nz)

    n = max(1, len(f1_list))
    metrics = ["F1-overlap", "BLEU", "ROUGE-L", "METEOR", "BERTScore-F1"]
    scores = [
        round(sum(f1_list)    / n * 100, 2),
        round(sum(bleu_list)  / n * 100, 2),
        round(sum(rouge_list) / n * 100, 2),
        round(sum(meteor_list)/ n * 100, 2),
        round(bert_f1_avg, 2),
    ]
    rows = [{"Metric": m, "Score": s} for m, s in zip(metrics, scores)]
    return pl.DataFrame(rows)

# === Run all models and combine outputs ===
all_summaries = []

for key, MODEL_NAME in MODELS.items():
    OUTPUT_CSV = f"chatbot_result/{scenario}/scenario_{scenario_no}_{scenario}_results_{key}.csv"

    print(f"\n🚀 Running Evaluation for: {MODEL_NAME}")

    result_df = pl.read_csv(OUTPUT_CSV)
    preds = result_df["prediction"].to_list()
    golds = result_df["response"].to_list()

    summary = compute_metrics(preds, golds).with_columns(pl.lit(key).alias("Model"))
    all_summaries.append(summary)

# Combine all models (long)
if all_summaries:
    final_df = pl.concat(all_summaries).select(["Model", "Metric", "Score"])
    final_df.write_csv(os.path.join(OUT_DIR, f"Scenario_{scenario_no}_Evaluation_AllModels.csv"))

    # Pivot for side-by-side comparison
    pivot_df = final_df.pivot(index="Metric", columns="Model", values="Score")
    pivot_df.write_csv(os.path.join(OUT_DIR, f"Scenario_{scenario_no}_Evaluation_Pivot.csv"))

    print("\n📊 Combined (pivot) comparison:")
    print(pivot_df)
    print("\n✅ Saved under 'Evaluation/'")
    print(f"- Scenario_{scenario_no}_Evaluation_AllModels.csv")
    print(f"- Scenario_{scenario_no}_Evaluation_Pivot.csv")
else:
    print("⚠️ No model results were processed.")
# Out:
# 🚀 Running Evaluation for: meta-llama/Llama-3.2-1B
#
# 🚀 Running Evaluation for: Qwen/Qwen3-0.6B-Base
#
# 🚀 Running Evaluation for: allenai/OLMo-2-0425-1B
#
# 📊 Combined (pivot) comparison:
# shape: (5, 4)
# ┌──────────────┬───────┬───────┬───────┐
# │ Metric       ┆ llama ┆ qwen  ┆ olmo  │
# │ ---          ┆ ---   ┆ ---   ┆ ---   │
# │ str          ┆ f64   ┆ f64   ┆ f64   │
# ╞══════════════╪═══════╪═══════╪═══════╡
# │ F1-overlap   ┆ 27.83 ┆ 12.79 ┆ 21.98 │
# │ BLEU         ┆ 9.07  ┆ 4.1   ┆ 7.77  │
# │ ROUGE-L      ┆ 17.8  ┆ 8.76  ┆ 15.19 │
# │ METEOR       ┆ 17.72 ┆ 7.92  ┆ 13.54 │
# │ BERTScore-F1 ┆ 19.2  ┆ 21.31 ┆ 4.08  │
# └──────────────┴───────┴───────┴───────┘
#
# ✅ Saved under 'Evaluation/'
# - Scenario_F_Evaluation_AllModels.csv
# - Scenario_F_Evaluation_Pivot.csv
# /tmp/ipykernel_5762/2364657735.py:155: DeprecationWarning: the argument `columns` for `DataFrame.pivot` is deprecated. It was renamed to `on` in version 1.0.0.
#   pivot_df = final_df.pivot(index="Metric", columns="Model", values="Score")
